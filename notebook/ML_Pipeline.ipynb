# %% [markdown]
# # LC25000 Cancer Classification – Full Pipeline
# This notebook executes the complete end-to-end ML workflow for the LC25000 Cancer Histopathology Classification Project, built around modular Python scripts for clarity, reproducibility, and interpretability.
#
# The pipeline automates; every stage from dataset preparation to model evaluation and explainability and is optimized for execution on a T4 GPU (Google Colab environment).
#
# ###1. Pipeline Overview
# Each section below represents a major stage in the workflow.
# You should run each cell sequentially; every step is independent and will display its output directly below.
# ### 2. Project Directory Setup
# Creates structured folders for data, results, and checkpoints.
# Ensures consistent organization and reproducibility.
# ### 3. Environment Setup
# Installs all dependencies listed in requirements.txt.
# Verifies GPU availability (T4 preferred).
# Includes optional setup for Apple Silicon (M1/M2) users.
# ### 4. Data Download & Extraction (Kaggle)
# Downloads the LC25000 dataset using the Kaggle API.
# Automatically extracts the dataset into the correct directory.
# ### 5. Dataset Splitting & Preparation
# Splits dataset into train, validation, and test sets.
# Uses a custom script (split_dataset.py) to avoid data leakage.
# Prepares folders compatible with torchvision.datasets.ImageFolder.
# ### 6. Exploratory Data Overview (EDA)
# Displays random samples, image dimensions, and class distribution.
# Helps verify dataset balance and quality before training.
# ### 7. Model Summary
# Loads and summarizes the ResNet18 architecture.
# Dynamically adjusts the classifier layer to match the dataset classes.
# Prints model summary using torchinfo.summary().
# ### 8. Training
# Trains the fine-tuned ResNet18 model using Adam optimizer and CrossEntropyLoss.
# Logs loss and accuracy for both training and validation.
# Saves the best model checkpoint automatically.
# ### 9. Plotting Training Metrics
# Generates static plots for loss and accuracy curves over epochs.
# Helps assess model convergence and generalization.
# ### 10. Animated Training Curves
# Creates smooth animations of accuracy/loss progression.
# Useful for presentations and visual summaries.
# ### 11. Evaluation on Test Set
# Loads the best saved model.
# Computes key performance metrics: Accuracy, Precision, Recall, F1-score.
# Generates and saves a classification report and confusion matrix.
# Exports per-image predictions as a CSV file for further analysis.
# ### 12. Grad-CAM Visualization
# Generates heatmaps highlighting regions influencing model predictions.
# Improves interpretability of CNN decisions.
# ### 13. Visualize Predictions (Grid View)
# Displays a grid of correctly predicted samples.
# Confirms that predictions align with visual intuition.
# ### 14. Visualize Misclassifications
# Displays incorrectly classified samples to analyze error patterns.
# Useful for identifying ambiguous or noisy data.
# ### 15. Grad-CAM Grid (Side-by-Side Analysis)
# Creates a combined visualization showing input images next to their Grad-CAM heatmaps.
# Provides a comprehensive interpretability overview.

# %% [markdown]
# ### PROJECT DIRECTORY SETUP
#
# This cell initializes the directory structure required for the LC25000 Cancer
# Classification pipeline. It ensures that all scripts, models, and output files are saved in the correct locations and that future cells can run without path errors.
# This step matters:
#
# Keeps the project modular, clean, and reproducible.
#
# Ensures all code references (for saving/loading) work automatically.
#
# Prevents "FileNotFoundError" during training, evaluation, or visualization.
#
# Run this cell **before any other steps** in the notebook.
#
# Folders created:
# - data/       → For raw and processed datasets
# - notebooks/  → For Jupyter notebooks and experiments
# - outputs/    → For generated figures, Grad-CAMs, and plots
# - results/    → For metrics, reports, and prediction CSV files
# - scripts/    → For modular Python scripts (dataset, model training)

# %%
import os

folders = [
    "data",
    "notebooks",
    "outputs",
    "results",
    "scripts"
]

# Create each folder if it doesn't exist
for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("✅ Project directory structure created.")
# Out:
# ✅ Project directory structure created.

# %%
# This command installs all required packages listed in the requirements file.

#!pip install -r /content/requirements_updated.txt --quiet

# %% [markdown]
# ### ENVIRONMENT SETUP
#
#
# ### Install Dependencies
#
#  Versions are pinned to avoid compatibility issues (esp. with PyTorch + torchvision + numpy)
#
# !pip install -q --upgrade pip
# !pip install -q torch==2.2.0 torchvision==0.17.0 torchaudio==2.2.0
# !pip install -q torchmetrics==1.3.2 tqdm==4.66.4 seaborn==0.13.2 scikit-learn==1.5.2 pandas==2.2.2 matplotlib==3.9.2
# !pip install -q opencv-python-headless==4.9.0.80
#
# ### Verify Versions
# import torch, torchvision, numpy as np, pandas as pd
# print(f"Torch: {torch.__version__}")
# print(f"Torchvision: {torchvision.__version__}")
# print(f"Numpy: {np.__version__}")
# print(f"Pandas: {pd.__version__}")
#
# ### Troubleshooting Tips
#
#    - If you see "module not found" or version conflict errors:
#        → Re-run this cell.
#    - If the Colab runtime restarts, re-run this setup cell.
#
#
#      !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
#     !pip install torchmetrics seaborn scikit-learn pandas matplotlib opencv-python-headless
#
# ### Notes:
#     This environment setup is optimized for Google Colab’s T4 GPU runtime,
#     which balances speed and memory efficiency for CNN training on LC25000.

# %%
# For M1/M2 Mac GPU support (uncomment if needed)
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ### Data Download & Extraction
#
# This section explains how to **download and extract the LC25000 histopathology dataset**, which serves as the foundation of this cancer image classification project.
# The dataset contains **25,000 high-resolution image patches (~1.8 GB)** evenly distributed across five classes:
# **Lung Adenocarcinoma**, **Lung Squamous Cell Carcinoma**, **Benign Lung Tissue**, **Colon Adenocarcinoma**, and **Benign Colon Tissue**.
#
#
#
# ####  **Purpose**
# This step ensures that the dataset is properly retrieved and extracted for training, validation, and testing.
# The data will be organized into folders compatible with PyTorch’s `ImageFolder` format, allowing easy integration with the training and evaluation scripts.
#
#
# #### **Important Notes**
# - **Skip this step** if you already have the dataset extracted in `data/Lung_and_Colon_Cancer/`.
# - The dataset is large (~1.8 GB) and may take several minutes to download and extract.
# - When using **Google Colab** or another cloud environment, you may need to re-download the dataset in each new session unless it is saved in persistent storage (e.g., Google Drive).
# - Once extraction is complete, all data will be located in the directory:
#   `data/Lung_and_Colon_Cancer/`.
#
#
#
# #### **Files Affected**
# - **`LC25000.zip`** → the downloaded dataset archive.
# - **Extracted contents** → stored under `data/Lung_and_Colon_Cancer/`.
#
#
#
# ###  How to Download Datasets from Kaggle Using the Kaggle API
#
# You can download the dataset programmatically using the **Kaggle API**, which provides a secure and reproducible way to access Kaggle datasets.
#
# ##### Steps to Obtain and Use Your Kaggle API Token:
# 1. Sign in to your Kaggle account at [https://www.kaggle.com](https://www.kaggle.com).
# 2. Click on your **profile picture → Account**.
# 3. Scroll down to the **API** section and click **“Create New API Token.”**
# 4. A file named **`kaggle.json`** will be downloaded automatically — it contains your **Kaggle username** and **API key**.
#
#
# ###  Upload `kaggle.json` to Your Notebook Environment
#
# In your notebook environment (e.g., **Google Colab** or **JupyterLab**):
#
# 1. Use the **file upload feature** (📎 icon) to upload your `kaggle.json` file to the current working directory.
# 2. Once uploaded, configure your environment to use these credentials so that the notebook can authenticate with Kaggle and download datasets automatically.
#
# After completing this setup, you’ll be ready to download and extract the LC25000 dataset directly into your `data/` directory.

# %%
import os
import shutil

# Install the Kaggle API client
# !pip install kaggle --quiet

# Create the .kaggle directory
os.makedirs(os.path.expanduser("~/.kaggle"), exist_ok=True)

# Move the kaggle.json file to the .kaggle directory
shutil.move("/content/kaggle.json", os.path.expanduser("~/.kaggle/kaggle.json"))

# Set the permissions of the kaggle.json file
os.chmod(os.path.expanduser("~/.kaggle/kaggle.json"), 0o600)

# %% [markdown]
# ###  Download and Unzip the Dataset
#
# Replace dataset-owner/dataset-name with the identifier of the dataset you wish to download. For example, to download the “Lung and Colon Cancer Histopathological Images” dataset:

# %%
# Download the dataset
# !kaggle datasets download -d andrewmvd/lung-and-colon-cancer-histopathological-images

# Unzip the downloaded dataset
# !unzip -q lung-and-colon-cancer-histopathological-images.zip -d data/
# Out:
# Dataset URL: https://www.kaggle.com/datasets/andrewmvd/lung-and-colon-cancer-histopathological-images
# License(s): CC-BY-SA-4.0
# ...
#  97% 1.71G/1.76G [00:17<00:01, 41.1MB/s]
# 100% 1.76G/1.76G [00:17<00:00, 110MB/s]

# %% [markdown]
# ### Dataset Splitting
#
# Split the raw dataset into train/val/test folders using the provided script.
#
# - **Input:** `data/Lung_and_Colon_Cancer/`
# - **Output:** `data/lc25000_split/` (with `train/`, `val/`, `test/` subfolders)
#
# This Step:
# - Ensures reproducible splits for training, validation, and testing.
# - Makes it easy to compare results across runs.
#
# Files affected:
# - Reads from `data/Lung_and_Colon_Cancer/`
# - Creates `data/lc25000_split/train/`, `val/`, `test/`

# %%
import os
import shutil
import random
from pathlib import Path

# Original dataset folder
SOURCE_DIR = Path("data/lung_colon_image_set")
#SOURCE_DIR = Path("data/Lung_and_Colon_Cancer")
TARGET_DIR = Path("data/lc25000_split")
SPLITS = ["train", "val", "test"]
SPLIT_RATIOS = [0.7, 0.15, 0.15]  # 70/15/15 split

def create_split_dirs(classes):
    for split in SPLITS:
        for class_name in classes:
            split_dir = TARGET_DIR / split / class_name
            split_dir.mkdir(parents=True, exist_ok=True)

def split_data():
    # Find the actual class directories within colon_image_sets and lung_image_sets
    actual_class_dirs = []
    for parent_dir in SOURCE_DIR.iterdir():
        if parent_dir.is_dir():
            for class_dir in parent_dir.iterdir():
                if class_dir.is_dir():
                    actual_class_dirs.append(class_dir)

    classes = [d.name for d in actual_class_dirs]

    create_split_dirs(classes)

    for class_dir in actual_class_dirs:
        images = list(class_dir.glob("*.jpeg"))
        random.shuffle(images)

        train_end = int(SPLIT_RATIOS[0] * len(images))
        val_end = train_end + int(SPLIT_RATIOS[1] * len(images))

        splits = {
            "train": images[:train_end],
            "val": images[train_end:val_end],
            "test": images[val_end:],
        }

        for split, image_paths in splits.items():
            for img_path in image_paths:
                # Use the actual class name for the target path
                target_path = TARGET_DIR / split / class_dir.name / img_path.name
                shutil.copy(img_path, target_path)

        print(f"✅ Split class '{class_dir.name}': {len(images)} images")

if __name__ == "__main__":
    random.seed(42)
    split_data()
    print("✅ Dataset split completed!")
# Out:
# ✅ Split class 'colon_n': 5000 images
# ✅ Split class 'colon_aca': 5000 images
# ✅ Split class 'lung_n': 5000 images
# ✅ Split class 'lung_scc': 5000 images
# ✅ Split class 'lung_aca': 5000 images
# ✅ Dataset split completed!

# %% [markdown]
# This cell checks whether the LC25000 dataset has been successfully
# downloaded and split into the expected folder structure.

# %%
import os
print(os.listdir('data/')) # List all items in the main 'data/' directory
if os.path.exists('data/lc25000_split'): # Check if the split dataset directory exists and display its contents
    print(os.listdir('data/lc25000_split'))
else:
    print('data/lc25000_split directory not found.')
# Out:
# ['lc25000_split', 'lung_colon_image_set']
# ['val', 'train', 'test']

# %% [markdown]
# ## Model Summary
#
# This step prints a summary of your model architecture, including each layer, output shape, and parameter count.
#
# This Step:
# - Useful for verifying your model structure before training.
# - Helps you understand the complexity and size of your model.
#
# - Uses `torchinfo.summary` to display a Keras-like summary table.

# %%
# !python -m scripts.model_summary --num_classes 5 --input_size 1 3 224 224
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 172MB/s]
# ...
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Kernel Shape              Mult-Adds
# ...

# %% [markdown]
# ##  Exploratory Data Analysis (EDA)
#
# Before training, it is essential to explore the LC25000 dataset to understand its composition and visual characteristics.
# This section provides insights into:
# - Class balance and sample distribution
# - Example images per class
# - Image dimensions and color intensity ranges
# - The effect of data augmentations
#
# These steps ensure we understand potential biases or artifacts before model training.
#
# Note for user: For the next two cells, do not pay attention to erorrs. You will get the results in the following cells.

# %%
#run this command to use the python script or run the followinging cell
#!python eda.py --data_dir data/LC25000_split/train

# %%
# --- COLAB ENVIRONMENT SETUP ---
# Cleans and installs all compatible dependencies for EDA and training.

# !pip install --upgrade --no-cache-dir --force-reinstall \
  torch==2.3.1 torchvision==0.18.1 torchaudio==2.3.1 \
  numpy==2.0.1 pandas==2.2.2 seaborn==0.13.2 matplotlib==3.9.2 \
  pillow==10.4.0 tqdm==4.66.5 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 35.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 308.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 299.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 278.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 181.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 213.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 193.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 301.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 414.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 324.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 303.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 302.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# This command forcefully reinstalls the latest version of SciPy.
# It is useful when encountering version conflicts or runtime errors
# related to dependencies that rely on SciPy (e.g., matplotlib, scikit-learn).
# The '--upgrade' flag ensures the newest version is installed, and '--force-reinstall' overrides any cached or corrupted installations.

# %%
# !pip install --upgrade --force-reinstall scipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 60.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 133.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.1
#     Uninstalling numpy-2.0.1:
#       Successfully uninstalled numpy-2.0.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.2
#     Uninstalling scipy-1.16.2:
#       Successfully uninstalled scipy-1.16.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.3 which is incompatible.
# ...

# %%
# --- EDA Section ---
# This section performs Exploratory Data Analysis (EDA) on the LC25000 dataset
# to understand its structure, content, and characteristics before model training.

import os
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
import seaborn as sns
import pandas as pd
from pathlib import Path

# Define data path
# This should point to the training split of the dataset.
DATA_DIR = "data/lc25000_split/train"  # adjust this path if needed

# Verify dataset structure and get actual class names
# This loop walks through the data directory to identify the actual class folders
# that contain image files.
actual_classes = []
class_counts = {}
if os.path.exists(DATA_DIR):
    for class_name in os.listdir(DATA_DIR):
        class_path = os.path.join(DATA_DIR, class_name)
        # Check if the entry is a directory and contains image files
        if os.path.isdir(class_path):
             # List files and check for common image extensions (case-insensitive)
            if any(File.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')) for File in os.listdir(class_path)):
                actual_classes.append(class_name)
                # Count only image files in the directory
                class_counts[class_name] = len([f for f in os.listdir(class_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))])
else:
    print(f"Error: DATA_DIR not found at {DATA_DIR}")

# Sort class names alphabetically for consistent ordering
actual_classes.sort()
print(f"Classes found: {actual_classes}")

# Print actual image counts per class
print("\nImage counts per class (actual):")
if class_counts:
    for cls, count in class_counts.items():
        print(f"  {cls}: {count}")
else:
    print("No class counts available.")


# This is for illustrative purposes to show the intended balanced distribution of the full dataset.
fake_counts = {cls: 5000 for cls in actual_classes}

# --- Plot class distribution (bars + labels at 5000) ---
# Visualize the (intended) class distribution using a bar plot.
if fake_counts:
    plt.figure(figsize=(8,5))
    sns.barplot(x=list(fake_counts.keys()), y=list(fake_counts.values()), palette="viridis")

    # Add numeric labels above bars for clarity
    for i, val in enumerate(fake_counts.values()):
        plt.text(i, val + 50, str(val), ha='center', va='bottom',
                 fontsize=10, fontweight='bold', color='black')

    plt.ylim(0, 5500) # Set y-axis limit slightly above max count
    plt.title("Class Distribution in LC25000 Dataset (5000 images per class)")
    plt.ylabel("Number of Images")
    plt.xticks(rotation=45) # Rotate x-axis labels for readability
    plt.tight_layout() # Adjust layout to prevent labels overlapping
    plt.show()
else:
    print("No classes found to plot class distribution.")


# --- Image Properties ---
# Collect sample image paths to check properties like size.
sample_paths = []
if actual_classes:
    for cls in actual_classes:
        class_dir = os.path.join(DATA_DIR, cls)
        if os.path.exists(class_dir):
             # Get the first image found in the directory for this class
             first_image = next((f for f in os.listdir(class_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))), None)
             if first_image:
                sample_paths.append(os.path.join(class_dir, first_image))
             else:
                print(f"Warning: No image files found in class directory: {class_dir}")
        else:
            print(f"Warning: Class directory not found: {class_dir}")

# Proceed only if sample_paths is not empty
if sample_paths:
    # Open sample images and get their dimensions (width, height)
    sizes = [Image.open(p).size for p in sample_paths]
    print("\nSample image sizes:", sizes)
else:
    print("\nNo sample image paths collected.")


# --- Display random images per class ---
# Function to display a grid of random sample images for each class.
def show_random_images_per_class(root, classes, n=5):
    """
    Displays a grid of random sample images for each given class.

    Args:
        root (str): The root directory containing the class subfolders.
        classes (list): A list of class names (directory names).
        n (int): The number of random images to display per class.
    """
    if not classes:
        print("No classes found to display images.")
        return

    # Create a figure and a grid of subplots (axes)
    fig, axes = plt.subplots(len(classes), n, figsize=(n*3, len(classes)*3))

    # Ensure axes is a 2D array even if there's only one class
    if len(classes) == 1:
        axes = np.array([axes])

    # Iterate through each class and each subplot column
    for i, cls in enumerate(classes):
        class_dir = os.path.join(root, cls)
        images_in_class = []
        # Get a list of all image files in the class directory
        if os.path.exists(class_dir):
             images_in_class = [f for f in os.listdir(class_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]

        print(f"Class '{cls}': Found {len(images_in_class)} images.") # Debug print

        # Determine how many images to display (up to n, or fewer if not enough images)
        if len(images_in_class) < n:
            print(f"Warning: Not enough images ({len(images_in_class)}) in class '{cls}' to display {n}. Displaying all available.")
            n_display = len(images_in_class)
        else:
            n_display = n

        # If there are images to display for this class
        if n_display > 0:
            # Select n_display random images
            images_to_display = random.sample(images_in_class, n_display)
            print(f"Class '{cls}': Displaying {n_display} images: {images_to_display}") # Debug print
            # Iterate through the selected images and display them in the subplot row
            for j, img_name in enumerate(images_to_display):
                 img_path = os.path.join(class_dir, img_name)
                 print(f"Class '{cls}': Attempting to load image: {img_path}") # Debug print

                 try:
                    img = Image.open(img_path)
                    axes[i, j].imshow(img)
                    axes[i, j].axis("off") # Turn off axes ticks and labels for images
                    if j == 0:
                        # Explicitly set the ylabel for the first subplot in the row
                        # This acts as the class label for the row
                        axes[i, j].set_ylabel(cls, fontsize=12, rotation=90, ha='right') # Add rotation and alignment
                 except Exception as e:
                     # Handle potential errors during image loading
                     print(f"Error loading image {img_path}: {e}")
                     axes[i, j].set_title("Load Error")
                     axes[i, j].axis("off")
        else:
             # If no images found for the class, display empty subplots with a message
             print(f"Class '{cls}': No images to display.") # Debug print
             for j in range(n):
                  axes[i, j].axis("off")
                  if j == 0:
                       axes[i, j].set_ylabel(cls, fontsize=12, rotation=90, ha='right') # Add rotation and alignment
                  axes[i, j].set_title("No Images")


    plt.suptitle("Random Samples per Class", fontsize=14, y=1.02) # Add a main title to the figure
    plt.tight_layout() # Adjust subplot parameters for a tight layout
    plt.show() # Display the figure

# Use the actual classes found to display random images
show_random_images_per_class(DATA_DIR, actual_classes)


# --- Compute brightness statistics ---
# Calculate and visualize the distribution of image brightness.
brightness_values = []
if actual_classes:
    # Iterate through each class
    for cls in actual_classes:
        class_dir = os.path.join(DATA_DIR, cls)
        images_in_class = []
        # Get list of image files
        if os.path.exists(class_dir):
             images_in_class = [f for f in os.listdir(class_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]

        # Sample a subset of images (up to 50) from each class
        if images_in_class:
            imgs_to_sample = random.sample(images_in_class, min(50, len(images_in_class)))
            # Process each sampled image
            for img_name in imgs_to_sample:
                img_path = os.path.join(class_dir, img_name)

                try:
                    # Open image, convert to grayscale ('L' mode), and calculate mean pixel value
                    img = Image.open(img_path).convert("L")
                    brightness_values.append(np.array(img).mean())
                except Exception as e:
                    print(f"Error processing image {img_path} for brightness: {e}")


# Plot the distribution of brightness values
if brightness_values:
    plt.figure(figsize=(6,4))
    sns.histplot(brightness_values, bins=30, kde=True) # Use seaborn for a histogram with KDE
    plt.title("Distribution of Image Brightness (Mean Grayscale Intensity)")
    plt.xlabel("Mean Pixel Value")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()
else:
    print("No brightness values collected. Could not process images.")


# --- Visualize data augmentation effects ---
# Define the set of data augmentation transformations
transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.9,1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.RandomRotation(15),
    transforms.ToTensor()
])

# Get a sample image path from an actual class to demonstrate augmentations
sample_img_for_aug = None
if actual_classes:
    # Iterate through actual class directories to find a sample image
    for cls in actual_classes:
        class_dir_aug = os.path.join(DATA_DIR, cls)
        if os.path.exists(class_dir_aug):
            # Find the first image file in the directory
            first_image = next((f for f in os.listdir(class_dir_aug) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))), None)
            if first_image:
                sample_img_for_aug = os.path.join(class_dir_aug, first_image)
                break # Found one, no need to check others


# Apply and display augmented versions of the sample image
if sample_img_for_aug:
    try:
        img = Image.open(sample_img_for_aug)

        fig, axes = plt.subplots(1, 5, figsize=(15, 3))
        # Apply the transform 5 times and display the results
        for i in range(5):
            aug_img = transform(img)
            # Ensure image is in the correct format for imshow (H, W, C) for color images
            if aug_img.shape[0] == 3:
                 axes[i].imshow(np.transpose(aug_img.numpy(), (1,2,0)))
            else: # Handle grayscale images if necessary (though expected to be color here)
                 axes[i].imshow(aug_img.squeeze().numpy(), cmap='gray')

            axes[i].axis("off")
            axes[i].set_title(f"Augmented {i+1}")
        plt.suptitle("Data Augmentation Examples", fontsize=14)
        plt.tight_layout()
        plt.show()
    except Exception as e:
        print(f"Error visualizing data augmentation: {e}")

else:
    print("Could not find a sample image to visualize data augmentation.")
# Out:
# Classes found: ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']
#
# Image counts per class (actual):
#   lung_n: 3500
#   colon_n: 3500
#   lung_scc: 3500
#   colon_aca: 3500
#   lung_aca: 3500
# /tmp/ipython-input-1794375523.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(fake_counts.keys()), y=list(fake_counts.values()), palette="viridis")
# Sample image sizes: [(768, 768), (768, 768), (768, 768), (768, 768), (768, 768)]
# Class 'colon_aca': Found 3500 images.
# Class 'colon_aca': Displaying 5 images: ['colonca4036.jpeg', 'colonca4632.jpeg', 'colonca584.jpeg', 'colonca3670.jpeg', 'colonca3919.jpeg']
# Class 'colon_aca': Attempting to load image: data/lc25000_split/train/colon_aca/colonca4036.jpeg
# Class 'colon_aca': Attempting to load image: data/lc25000_split/train/colon_aca/colonca4632.jpeg
# ...

# %% [markdown]
# ## Model-Comparison Code (ResNet18 vs ResNet34 vs EfficientNetB0)
#
# ### Model Comparison: ResNet18 vs ResNet34 vs EfficientNetB0
#
# This step compares multiple deep learning architectures to evaluate their performance on the LC25000 dataset.
# Each model is trained and validated under identical conditions to determine the most effective network for cancer image classification.

# %% [markdown]
# This package provides additional evaluation metrics
# (e.g., Precision, Recall, F1-score) for PyTorch models.
# The '--quiet' flag suppresses installation logs for cleaner output.

# %%
#!pip install torchmetrics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 22.0 MB/s eta 0:00:00

# %%
# FAST MODEL COMPARISON → FINAL TEST EVALUATION (Colab-Optimized)

# This section performs quick comparative training of multiple CNN architectures (ResNet18, ResNet34, EfficientNetB0)
# on a smaller subset of the LC25000 dataset to determine which performs best.
# It includes training, validation, metric logging, and a final test evaluation of the best-performing model.


import torch, torch.nn as nn, torch.optim as optim
from torchvision import models, transforms, datasets
from torch.utils.data import DataLoader, Subset
import torchmetrics, time, copy, os, random, pandas as pd, numpy as np
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# CONFIGURATION

# Define paths, hyperparameters, and runtime settings.
# DATA_DIR: Path to the prepared dataset (already split into train/val/test).
# DEVICE: Automatically selects GPU (CUDA) if available; otherwise CPU.
# BATCH_SIZE, LR, WEIGHT_DECAY: Standard training hyperparameters.
# SUBSET_RATIO: Use only a subset (20%) of data for faster comparisons.
# USE_AMP: Enables automatic mixed precision (faster GPU training).
# SAVE_DIR: Folder where the best model and results will be saved.

DATA_DIR = "data/lc25000_split"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 32
LR = 1e-3
WEIGHT_DECAY = 1e-4
SUBSET_RATIO = 0.2          # 20% for faster training
IMAGE_SIZE = 160
USE_AMP = True
SAVE_DIR = "./content/best_model"
os.makedirs(SAVE_DIR, exist_ok=True)
print(f"✅ Using device: {DEVICE}")

# 🎨 DATA TRANSFORMS

# Apply data augmentation for the training set and normalization for all datasets.
# Training: Includes augmentations (flips, rotations, color jitter) to prevent overfitting.
# Validation/Test: Only resizing and normalization (no augmentations).

train_tfms = transforms.Compose([
    transforms.RandomResizedCrop(IMAGE_SIZE, scale=(0.9,1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])
val_tfms = transforms.Compose([
    transforms.Resize((IMAGE_SIZE,IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])

# DATASETS

# Load train, validation, and test sets using ImageFolder.
# A smaller random subset of training/validation data is used for quick testing.

train_ds_full = datasets.ImageFolder(os.path.join(DATA_DIR,"train"), transform=train_tfms)
val_ds_full   = datasets.ImageFolder(os.path.join(DATA_DIR,"val"), transform=val_tfms)
test_ds_full  = datasets.ImageFolder(os.path.join(DATA_DIR,"test"), transform=val_tfms)
num_classes = len(train_ds_full.classes)

# Randomly select subset indices for faster training
train_idx = random.sample(range(len(train_ds_full)), int(len(train_ds_full)*SUBSET_RATIO))
val_idx   = random.sample(range(len(val_ds_full)),   int(len(val_ds_full)*SUBSET_RATIO))
train_ds_sub = Subset(train_ds_full, train_idx)
val_ds_sub   = Subset(val_ds_full,   val_idx)

train_dl = DataLoader(train_ds_sub, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
val_dl   = DataLoader(val_ds_sub,   batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
print(f"📊 Using {len(train_ds_sub)} train / {len(val_ds_sub)} val images for model comparison.")


# METRICS INITIALIZATION

# Initialize TorchMetrics objects for accuracy, precision, recall, and F1-score.

def init_metrics(num_classes):
    return {
        "acc": torchmetrics.Accuracy(task="multiclass", num_classes=num_classes).to(DEVICE),
        "prec": torchmetrics.Precision(task="multiclass", num_classes=num_classes, average="macro").to(DEVICE),
        "rec": torchmetrics.Recall(task="multiclass", num_classes=num_classes, average="macro").to(DEVICE),
        "f1": torchmetrics.F1Score(task="multiclass", num_classes=num_classes, average="macro").to(DEVICE)
    }

# TRAINING FUNCTION

# Defines a modular training loop with mixed precision, early stopping,
# and live metric computation for both training and validation phases.

def train_model(model, name, train_dl, val_dl, epochs=10, patience=3):
    criterion = nn.CrossEntropyLoss()      # Multi-class loss function
    optimizer = optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=LR, weight_decay=WEIGHT_DECAY)
    scaler = torch.cuda.amp.GradScaler(enabled=USE_AMP)
    metrics = init_metrics(num_classes)

# Track best model and progress
    best_acc, best_epoch, best_wts, best_val_loss, no_imp = 0.0, 0, copy.deepcopy(model.state_dict()), float("inf"), 0
    hist = {"train_loss":[], "val_loss":[], "train_acc":[], "val_acc":[]}
    start = time.time()

    for epoch in range(epochs):
        print(f"\n🔹 {name} | Epoch {epoch+1}/{epochs}")
        for phase in ["train","val"]:
          # Toggle between training and validation modes
            model.train() if phase=="train" else model.eval()
            dl = train_dl if phase=="train" else val_dl
            run_loss = 0.0
            for m in metrics.values(): m.reset()

            for x,y in tqdm(dl, desc=f"{phase.title()}"):
                x,y = x.to(DEVICE), y.to(DEVICE)
                optimizer.zero_grad()
                with torch.set_grad_enabled(phase=="train"):
                    with torch.cuda.amp.autocast(enabled=USE_AMP):  # Enable mixed precision
                        out = model(x)
                        loss = criterion(out,y)
                    _, preds = torch.max(out,1) # Convert logits to class indices
                    if phase=="train":
                      # Backpropagation only in training phase
                        scaler.scale(loss).backward()
                        scaler.step(optimizer)
                        scaler.update()
                run_loss += loss.item()*x.size(0)
                for m in metrics.values(): m.update(preds,y)

            # Epoch statistics
            loss_epoch = run_loss/len(dl.dataset)
            vals = {k:m.compute() for k,m in metrics.items()}
            print(f"{phase.title()} | Loss:{loss_epoch:.4f} | Acc:{vals['acc']:.4f} | P:{vals['prec']:.4f} | R:{vals['rec']:.4f} | F1:{vals['f1']:.4f}")
            hist[f"{phase}_loss"].append(loss_epoch)
            hist[f"{phase}_acc"].append(vals['acc'].item())

            # Track best model based on validation loss and accuracy
            if phase=="val":
                if loss_epoch<best_val_loss-1e-4:
                    best_val_loss, no_imp = loss_epoch, 0
                    best_wts = copy.deepcopy(model.state_dict())
                else:
                    no_imp += 1
                if vals["acc"]>best_acc:
                    best_acc, best_epoch = vals["acc"], epoch+1
        # Early stopping if validation loss does not improve
        if no_imp>=patience:
            print(f"🛑 Early stopping at epoch {epoch+1}")
            break
    # Load best model weights after training
    model.load_state_dict(best_wts)
    total_time=(time.time()-start)/60
    print(f"✅ {name} done | Best epoch {best_epoch} | Val Acc {best_acc:.4f}")
    return {"Model":name,"Val Accuracy":best_acc.item(),"Train Time (min)":total_time}, hist, model


#  MODEL PREPARATION

# Loads pretrained ResNet18, ResNet34, or EfficientNetB0,
# freezes earlier layers, and replaces final classification layers.

def prepare_model(name):
    if name=="ResNet18":
        m=models.resnet18(weights="IMAGENET1K_V1")
        [setattr(p,"requires_grad",False) for p in list(m.parameters())[:-1]]
        m.fc=nn.Linear(m.fc.in_features,num_classes)
    elif name=="ResNet34":
        m=models.resnet34(weights="IMAGENET1K_V1")
        [setattr(p,"requires_grad",False) for p in list(m.parameters())[:-1]]
        m.fc=nn.Linear(m.fc.in_features,num_classes)
    else:
        m=models.efficientnet_b0(weights="IMAGENET1K_V1")
        [setattr(p,"requires_grad",False) for p in list(m.parameters())[:-2]]
        m.classifier[1]=nn.Linear(m.classifier[1].in_features,num_classes)
    return m.to(DEVICE)

# STAGE 1: FAST MODEL COMPARISON

# Trains and validates each model (ResNet18, ResNet34, EfficientNetB0)
# with reduced epochs for quick performance evaluation.

models_to_run={"ResNet18":(8,3),"ResNet34":(10,4),"EfficientNetB0":(12,5)}
results, histories, trained_models = [], {}, {}

for name,(epochs,pat) in models_to_run.items():
    model=prepare_model(name)
    r,h,m=train_model(model,name,train_dl,val_dl,epochs,pat)
    results.append(r); histories[name]=h; trained_models[name]=m

# Create a summary table of validation performance
df=pd.DataFrame(results)
display(df)

# Plot validation accuracy comparison

plt.figure(figsize=(8,4))
for n,h in histories.items(): plt.plot(h["val_acc"],label=n)
plt.legend(); plt.grid(True)
plt.title("Validation Accuracy (Subset Training)")
plt.xlabel("Epoch"); plt.ylabel("Accuracy"); plt.show()


# IDENTIFY BEST MODEL & SAVE

# Finds the model with highest validation accuracy and saves it for test evaluation.

best_model_name = df.sort_values("Val Accuracy", ascending=False).iloc[0]["Model"]
best_model = trained_models[best_model_name]
torch.save(best_model.state_dict(), f"{SAVE_DIR}/final_best_{best_model_name}.pth")
print(f"🏆 Best model: {best_model_name} | Saved to {SAVE_DIR}")


# STAGE 2: FINAL TEST EVALUATION (using best model)

# Evaluates the best-performing model on the full test dataset,
# generates classification report and confusion matrix.

test_dl = DataLoader(test_ds_full, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
best_model.eval()
y_true, y_pred = [], []

with torch.no_grad():
    for x, y in tqdm(test_dl, desc="Testing"):
        x, y = x.to(DEVICE), y.to(DEVICE)
        out = best_model(x)
        _, preds = torch.max(out, 1)
        y_true.extend(y.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# Generate and save a detailed classification report
report = classification_report(y_true, y_pred, target_names=test_ds_full.classes, output_dict=True)
report_df = pd.DataFrame(report).transpose()
report_path = f"{SAVE_DIR}/classification_report.csv"
report_df.to_csv(report_path)
print(f"📊 Classification report saved to {report_path}")

# Generate and save the confusion matrix visualization
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_ds_full.classes)
plt.figure(figsize=(6,6))
disp.plot(cmap="Blues", xticks_rotation=45, colorbar=False)
plt.title(f"{best_model_name} - Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{SAVE_DIR}/confusion_matrix.png")
plt.show()

print("✅ Fast comparison & final test evaluation complete!")
# Out:
# ✅ Using device: cuda
# 📊 Using 3500 train / 750 val images for model comparison.
#
# 🔹 ResNet18 | Epoch 1/8
# Train:   0%|          | 0/110 [00:00<?, ?it/s]
# Train | Loss:0.6956 | Acc:0.7791 | P:0.7796 | R:0.7795 | F1:0.7794
# Val:   0%|          | 0/24 [00:00<?, ?it/s]
# Val | Loss:0.3143 | Acc:0.9147 | P:0.9188 | R:0.9146 | F1:0.9133
#
# 🔹 ResNet18 | Epoch 2/8
# Train:   0%|          | 0/110 [00:00<?, ?it/s]
# Train | Loss:0.3236 | Acc:0.9006 | P:0.9005 | R:0.9006 | F1:0.9004
# Val:   0%|          | 0/24 [00:00<?, ?it/s]
# Val | Loss:0.2279 | Acc:0.9267 | P:0.9275 | R:0.9259 | F1:0.9255
#
# 🔹 ResNet18 | Epoch 3/8
# Train:   0%|          | 0/110 [00:00<?, ?it/s]
# Train | Loss:0.2663 | Acc:0.9134 | P:0.9135 | R:0.9135 | F1:0.9134
# Val:   0%|          | 0/24 [00:00<?, ?it/s]
# Val | Loss:0.1885 | Acc:0.9387 | P:0.9390 | R:0.9378 | F1:0.9376
#
# 🔹 ResNet18 | Epoch 4/8
# Train:   0%|          | 0/110 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## Training
#
# This section trains the **ResNet18** model on the **LC25000 histopathology dataset** using a transfer learning approach.
# A pretrained ResNet18 backbone (trained on ImageNet) is fine-tuned on the cancer classification task, allowing the model to leverage learned low-level visual features such as edges, textures, and color patterns; all crucial for histopathology analysis.
#
#
# #### Training Configuration
# - **Optimizer:** Adam (adaptive gradient optimization)
# - **Loss Function:** CrossEntropyLoss (multi-class classification)
# - **Learning Rate:** `1e-3` with **weight decay** to prevent overfitting
# - **Batch Size:** 32 (adjustable based on memory limits)
# - **Mixed Precision Training:** Enabled via `torch.cuda.amp` for faster GPU computation
# - **Early Stopping:** Stops training automatically if validation loss does not improve
# - **Checkpoints:** Best-performing model (highest validation accuracy) is saved automatically in
#   `saved_models/` with a timestamped filename
# - **Metrics Tracked:** Training/validation loss, accuracy, precision, recall, and F1-score (using TorchMetrics)
#
#
# ####Outputs Generated
# - **Model Checkpoint:** Best version of the trained model
# - **Training Curves:** Plots of accuracy and loss per epoch
# - **Animated Learning Curve:** Visualization of model convergence over time
# - **Logs and Reports:** Saved under the `results/` directory for further analysis
#
#
#
# ####Conceptual Insight
# During this phase, the network fine-tunes its convolutional filters to detect **microscopic tissue morphology** and **cellular structures** that differentiate healthy and cancerous tissues.
# By minimizing the loss function, the model progressively learns to map pixel-level features to their corresponding diagnostic classes.
#
#
#
# #### Tips
# - You can modify **epochs**, **learning rate**, or **augmentation parameters** in `scripts/train.py` to experiment with training performance.
# - Use a **GPU (T4 recommended)** to accelerate training — running on CPU will be significantly slower.
# - Monitor validation accuracy and loss plots to identify overfitting or underfitting trends.
# - Ensure your dataset paths and environment are correctly configured before starting this step.

# %%
#!python -m scripts.train

# %%
# This ensures compatibility between NumPy and scikit-learn.
"""!pip install --upgrade --force-reinstall numpy==1.26.4 scikit-learn --quiet
import numpy as np, sklearn
print("✅ Numpy:", np.__version__, "| Sklearn:", sklearn.__version__)"""
# Out:
# '!pip install --upgrade --force-reinstall numpy==1.26.4 scikit-learn --quiet\nimport numpy as np, sklearn\nprint("✅ Numpy:", np.__version__, "| Sklearn:", sklearn.__version__)'

# %% [markdown]
# TorchMetrics provides ready-to-use performance metrics such as Accuracy, Precision, Recall, and F1-Score for PyTorch models.
# These metrics are used during training and evaluation to track model performance more precisely.

# %%
# !pip install torchmetrics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 23.1 MB/s eta 0:00:00

# %%
# --- Advanced Training Section ---

# Description:

#   This cell defines and runs a flexible, modular deep learning pipeline for
#   histopathological cancer image classification (LC25000 dataset).
#   It addresses the professor's feedback by:
#       Improving documentation
#       Adding runtime customization (augmentation, loss, metrics)
#       Using torchmetrics for standardized evaluation
#       Implementing checkpoint resume support for Colab disconnections


### Import Required Libraries ###

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau, OneCycleLR
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, time, copy
from tqdm.auto import tqdm
from PIL import Image
import torchmetrics  # Provides modular metrics for accuracy, precision, recall, F1


### Core Configuration ###

# These parameters control data paths, model structure, and hardware settings.
DATA_DIR = "data/lc25000_split"    # Root directory containing 'train' and 'val' folders
SAVE_DIR = "./content/best_model"  # Directory for saving checkpoints and logs
BATCH_SIZE = 32                    # Batch size for training and validation
EPOCHS = 30                        # Total number of training epochs
MODEL_NAME = "resnet18"            # Base CNN model architecture
OPTIMIZER_NAME = "adamw"           # Optimizer: AdamW or SGD
SCHEDULER_NAME = "plateau"         # Learning rate scheduler: 'plateau' or 'onecycle'
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # Auto GPU selection


### Experiment Customization Parameters ###

# These options allow flexible experimentation without modifying core code.
AUGMENTATION_STRENGTH = "moderate"   # 'light' | 'moderate' | 'strong'
LOSS_TYPE = "crossentropy"           # 'crossentropy' | 'label_smoothing' | 'focal'
METRIC_SET = ["accuracy", "precision", "recall", "f1"]  # Which metrics to compute
LR = 1e-3                            # Learning rate
WEIGHT_DECAY = 1e-4                  # Weight decay (L2 regularization)
MOMENTUM = 0.9                       # Momentum for SGD

# Create checkpoint directory if needed
os.makedirs(SAVE_DIR, exist_ok=True)
print(f"✅ Checkpoints will be saved to: {os.path.abspath(SAVE_DIR)}")

### Data Augmentation Pipelines ###

# Dynamically define augmentations based on strength setting.
if AUGMENTATION_STRENGTH == "light":
    # Minimal augmentations — good for already balanced datasets.
    train_tfms = transforms.Compose([
        transforms.Resize((224,224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
elif AUGMENTATION_STRENGTH == "strong":
    # Heavy augmentations — more diversity, useful for small datasets.
    train_tfms = transforms.Compose([
        transforms.RandomResizedCrop(224, scale=(0.8,1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4),
        transforms.RandomRotation(25),
        transforms.RandomAffine(degrees=0, shear=10),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
else:
    # Moderate — balanced augmentations for LC25000.
    train_tfms = transforms.Compose([
        transforms.RandomResizedCrop(224, scale=(0.9,1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.ColorJitter(brightness=0.2, contrast=0.2),
        transforms.RandomRotation(15),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

# Validation data should only be normalized — no augmentations.
val_tfms = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])


### Custom Dataset Class ###

class CancerDataset(Dataset):
    """Custom PyTorch Dataset for LC25000 histopathology images."""
    def __init__(self, data_list, transform=None):
        self.data_list = data_list  # List of (image_path, label_index) tuples
        self.transform = transform  # Torchvision transforms to apply

    def __len__(self):
        return len(self.data_list)

    def __getitem__(self, idx):
        img_path, label = self.data_list[idx]
        img = Image.open(img_path).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, label


### Dataset Collection Utility

def collect_data_list(data_root):
    """
    Recursively scans a directory to collect image paths and assign class labels.
    Each subfolder is treated as a class.
    """
    data_list = []
    class_names = sorted([d.name for d in os.scandir(data_root) if d.is_dir()])
    class_to_idx = {cls_name: i for i, cls_name in enumerate(class_names)}

    for class_name in class_names:
        class_dir = os.path.join(data_root, class_name)
        for img_name in os.listdir(class_dir):
            if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
                data_list.append((os.path.join(class_dir, img_name), class_to_idx[class_name]))
    return data_list, class_names

# Collect training and validation samples
train_data_list, class_names = collect_data_list(os.path.join(DATA_DIR, "train"))
val_data_list, _ = collect_data_list(os.path.join(DATA_DIR, "val"))

# Create Dataset and DataLoader objects
train_dl = DataLoader(CancerDataset(train_data_list, train_tfms), batch_size=BATCH_SIZE, shuffle=True)
val_dl = DataLoader(CancerDataset(val_data_list, val_tfms), batch_size=BATCH_SIZE, shuffle=False)

print(f"📦 Loaded {len(train_data_list)} training and {len(val_data_list)} validation images across {len(class_names)} classes.")


### Model Setup ###

num_classes = len(class_names)
model_fn = getattr(models, MODEL_NAME)        # dynamically load chosen model
model = model_fn(pretrained=True)             # load pretrained weights
model.fc = nn.Linear(model.fc.in_features, num_classes)  # replace final layer
model = model.to(DEVICE)


### Optimizer, Scheduler, and Loss Function ###

if OPTIMIZER_NAME == "adamw":
    optimizer = optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
else:
    optimizer = optim.SGD(model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# --- Flexible Loss Selection ---
if LOSS_TYPE == "crossentropy":
    criterion = nn.CrossEntropyLoss()
elif LOSS_TYPE == "label_smoothing":
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
elif LOSS_TYPE == "focal":
    # Custom focal loss to handle class imbalance.
    from torch.nn.functional import cross_entropy
    class FocalLoss(nn.Module):
        def __init__(self, gamma=2.0, alpha=0.25):
            super().__init__()
            self.gamma = gamma
            self.alpha = alpha
        def forward(self, inputs, targets):
            ce = cross_entropy(inputs, targets, reduction='none')
            pt = torch.exp(-ce)
            return (self.alpha * (1 - pt) ** self.gamma * ce).mean()
    criterion = FocalLoss()
else:
    raise ValueError(f"Unsupported LOSS_TYPE: {LOSS_TYPE}")

# Learning rate scheduling strategy
if SCHEDULER_NAME == "plateau":
    scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=3, factor=0.2)
else:
    scheduler = OneCycleLR(optimizer, max_lr=0.01, steps_per_epoch=len(train_dl), epochs=EPOCHS)


### Checkpoint Management (for Resume Training) ###

CHECKPOINT_PATH = os.path.join(SAVE_DIR, f"checkpoint_{MODEL_NAME}.pth")
final_model_path = os.path.join(SAVE_DIR, f"final_best_{MODEL_NAME}.pth")
history_path = os.path.join(SAVE_DIR, f"training_history_{MODEL_NAME}.csv")

start_epoch, best_acc = 0, 0.0
best_val_loss = float('inf')
history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
best_wts = copy.deepcopy(model.state_dict())

# If a checkpoint exists, resume from it
if os.path.exists(CHECKPOINT_PATH):
    print(f"🔄 Resuming from checkpoint: {CHECKPOINT_PATH}")
    checkpoint = torch.load(CHECKPOINT_PATH, map_location=DEVICE)
    model.load_state_dict(checkpoint["model_state"])
    optimizer.load_state_dict(checkpoint["optimizer_state"])
    scheduler.load_state_dict(checkpoint["scheduler_state"])
    start_epoch = checkpoint["epoch"] + 1
    best_acc = checkpoint["best_acc"]
    history = checkpoint.get("history", history)
    print(f"✅ Resumed from epoch {start_epoch} | Best Val Acc: {best_acc:.4f}")
else:
    print("⚠️ No existing checkpoint found — starting new training.")

### Dynamic Metric Setup ###

metric_objects = {}
if "accuracy" in METRIC_SET:
    metric_objects["accuracy"] = torchmetrics.Accuracy(task="multiclass", num_classes=num_classes).to(DEVICE)
if "precision" in METRIC_SET:
    metric_objects["precision"] = torchmetrics.Precision(task="multiclass", num_classes=num_classes, average='macro').to(DEVICE)
if "recall" in METRIC_SET:
    metric_objects["recall"] = torchmetrics.Recall(task="multiclass", num_classes=num_classes, average='macro').to(DEVICE)
if "f1" in METRIC_SET:
    metric_objects["f1"] = torchmetrics.F1Score(task="multiclass", num_classes=num_classes, average='macro').to(DEVICE)


### Training Loop with Early Stopping ###

early_stop_patience = 5
no_improve_epochs = 0

for epoch in range(start_epoch, EPOCHS):
    print(f"\nEpoch {epoch+1}/{EPOCHS}")
    for phase in ["train", "val"]:
        model.train() if phase == "train" else model.eval()
        dataloader = train_dl if phase == "train" else val_dl
        running_loss = 0.0

        # Reset all torchmetrics each epoch
        for m in metric_objects.values(): m.reset()

        for inputs, labels in tqdm(dataloader, desc=f"{phase.title()} Batches", leave=False):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            # Forward + backward pass
            with torch.set_grad_enabled(phase == "train"):
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                if phase == "train":
                    loss.backward()
                    optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            for m in metric_objects.values():
                m.update(preds, labels)

        # Compute epoch-level statistics
        epoch_loss = running_loss / len(dataloader.dataset)
        computed = {k: v.compute() for k, v in metric_objects.items()}
        epoch_acc = computed.get("accuracy", torch.tensor(0.0))

        print(f"{phase.title()} Loss: {epoch_loss:.4f} | " +
              " | ".join([f"{k.title()}: {v:.4f}" for k, v in computed.items()]))

        # Record metrics
        if phase == "train":
            history["train_loss"].append(epoch_loss)
            history["train_acc"].append(epoch_acc.item())
        else:
            history["val_loss"].append(epoch_loss)
            history["val_acc"].append(epoch_acc.item())
            scheduler.step(epoch_loss)

            # Track improvement for early stopping
            if epoch_loss < best_val_loss - 1e-4:
                best_val_loss = epoch_loss
                no_improve_epochs = 0
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_wts = copy.deepcopy(model.state_dict())
                    print(f"✅ New best model at epoch {epoch+1} | Val Acc: {best_acc:.4f}")
            else:
                no_improve_epochs += 1

    # Save progress periodically
    if (epoch + 1) % 2 == 0 or no_improve_epochs >= early_stop_patience:
        checkpoint_data = {
            "epoch": epoch,
            "model_state": model.state_dict(),
            "optimizer_state": optimizer.state_dict(),
            "scheduler_state": scheduler.state_dict(),
            "best_acc": best_acc,
            "history": history
        }
        torch.save(checkpoint_data, CHECKPOINT_PATH)
        print(f"💾 Checkpoint saved at epoch {epoch+1}")

    if no_improve_epochs >= early_stop_patience:
        print(f"\n🛑 Early stopping triggered at epoch {epoch+1}")
        break


### Save Final Model and Training Curves ###

model.load_state_dict(best_wts)
torch.save(model.state_dict(), final_model_path)
print(f"\n✅ Final best model saved to: {os.path.abspath(final_model_path)}")

pd.DataFrame(history).to_csv(history_path, index=False)
print(f"📊 Training history saved to: {os.path.abspath(history_path)}")

# Visualize training and validation performance curves
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Val Loss")
plt.title("Loss Curves")
plt.xlabel("Epochs"); plt.ylabel("Loss"); plt.legend()

plt.subplot(1,2,2)
plt.plot(history["train_acc"], label="Train Acc")
plt.plot(history["val_acc"], label="Val Acc")
plt.title("Accuracy Curves")
plt.xlabel("Epochs"); plt.ylabel("Accuracy"); plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ✅ Checkpoints will be saved to: /content/content/best_model
# 📦 Loaded 17500 training and 3750 validation images across 5 classes.
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 189MB/s]
# ...

# %% [markdown]
# ## Plotting Training Metrics
#
# This step visualizes the **training and validation performance** of the model over time using plots of **loss** and **accuracy**.
# These visualizations are generated from the saved training metrics file and provide valuable insights into how well the model is learning and generalizing during fine-tuning.
#
#
# ####Inputs and Outputs
# - **Input:** `results/training_metrics_<timestamp>.json` (automatically saved after training)
# - **Outputs:** Static and animated plots stored in the `outputs/` directory
#
# The plots include:
# - **Training vs Validation Accuracy:** Measures how well the model generalizes to unseen data
# - **Training vs Validation Loss:** Indicates how effectively the model minimizes prediction errors
#
#
#
# This step, Visualizing training curves, allows you to:
# - Identify **overfitting** (training accuracy increases while validation accuracy stagnates or drops)
# - Detect **underfitting** (both accuracies remain low)
# - Evaluate whether **early stopping** was triggered at the right time
# - Assess **training stability** and model convergence trends
#
#
#
# #### Conceptual Insight
# By analyzing the accuracy and loss curves, you can interpret the model’s learning dynamics:
# - A smooth, gradually converging loss curve suggests stable optimization.
# - Diverging loss or fluctuating accuracy may indicate an overly high learning rate or insufficient regularization.
# - Consistent alignment between training and validation curves reflects strong generalization.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# Define the path to the training history CSV file
history_path = "./content/best_model/training_history_resnet18.csv"

# Check if the history file exists and read it
if os.path.exists(history_path):
    history_df = pd.read_csv(history_path)

    # Extract metrics from the DataFrame
    epochs = history_df.index + 1 # Use index as epochs, starting from 1
    train_losses = history_df["train_loss"]
    val_losses = history_df["val_loss"]
    train_accuracies = history_df["train_acc"]
    val_accuracies = history_df["val_acc"]

    # Check if precision and recall columns exist
    has_precision_recall = "train_precision" in history_df.columns and "val_precision" in history_df.columns and \
                           "train_recall" in history_df.columns and "val_recall" in history_df.columns

    # Adjust figure size based on whether precision/recall are available
    if has_precision_recall:
        fig, axes = plt.subplots(2, 2, figsize=(12, 8))
        ax1, ax2, ax3, ax4 = axes.flatten()
    else:
        fig, axes = plt.subplots(1, 2, figsize=(12, 5))
        ax1, ax2 = axes.flatten()
        ax3, ax4 = None, None # Set to None if not plotting precision/recall


    # Plot Loss
    ax1.plot(epochs, train_losses, label='Train Loss')
    ax1.plot(epochs, val_losses, label='Val Loss')
    ax1.set_title("Loss Over Epochs")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.legend()
    ax1.grid(True)


    # Plot Accuracy
    ax2.plot(epochs, train_accuracies, label='Train Acc')
    ax2.plot(epochs, val_accuracies, label='Val Acc')
    ax2.set_title("Accuracy Over Epochs")
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel("Accuracy")
    ax2.legend()
    ax2.set_ylim(0, 1.05) # Ensure accuracy is between 0 and 1
    ax2.grid(True)

    # Plot Precision and Recall if available
    if has_precision_recall:
        train_precisions = history_df["train_precision"]
        val_precisions = history_df["val_precision"]
        train_recalls = history_df["train_recall"]
        val_recalls = history_df["val_recall"]

        ax3.plot(epochs, train_precisions, label='Train Precision')
        ax3.plot(epochs, val_precisions, label='Val Precision')
        ax3.set_title("Precision Over Epochs")
        ax3.set_xlabel("Epoch")
        ax3.set_ylabel("Precision")
        ax3.legend()
        ax3.set_ylim(0, 1.05)
        ax3.grid(True)

        ax4.plot(epochs, train_recalls, label='Train Recall')
        ax4.plot(epochs, val_recalls, label='Val Recall')
        ax4.set_title("Recall Over Epochs")
        ax4.set_xlabel("Epoch")
        ax4.set_ylabel("Recall")
        ax4.legend()
        ax4.set_ylim(0, 1.05)
        ax4.grid(True)


    plt.tight_layout()
    plt.show()

else:
    print(f"Error: Training history file not found at {history_path}")
    print("Please ensure the training step (Section 5) has been run successfully.")

# %% [markdown]
# ## Animated Training Curves
#
# This section creates an **animated visualization** of the model’s **training and validation performance** across epochs.
# The animation dynamically displays changes in **loss** and **accuracy** over time, allowing you to observe how the model converges, stabilizes, or overfits as training progresses.
#
#
# ####Purpose
# - Converts recorded training metrics (from the JSON file in `results/`) into a smooth animation.
# - Shows **epoch-by-epoch progression** of loss reduction and accuracy improvement.
# - Provides a more intuitive understanding of how quickly and effectively the model learns.
#
#
# #### Inputs and Outputs
# - **Input:** `results/training_metrics_<timestamp>.json` (generated automatically during training)
# - **Output:** An animated `.mp4` or inline animation saved under `outputs/`
#
# Two display options are available:
# 1. **Notebook Cell (Recommended for Colab/Jupyter):**
#    Renders the animation directly in the notebook output cell for interactive visualization.
# 2. **Standalone Script (for local use):**
#    Run in a terminal using:
#    `python -m scripts.animate_training_curves`
#    Displays the animation in a separate window.
#
#
# #### This Step:
# - Visualizes how quickly the model **learns** and **stabilizes** over epochs.
# - Helps identify **plateaus**, **sudden performance drops**, or **overfitting patterns** in real time.
# - Complements static plots by showing the **temporal evolution** of training progress.
#
#
# ####Conceptual Insight
# Animated learning curves offer a **temporal perspective** on model optimization:
# - **Gradual convergence:** Smooth and consistent improvement → stable learning.
# - **Fluctuating validation accuracy:** Possible overfitting or noisy data.
# - **Plateauing loss:** Indicates that the model has reached its learning capacity.
#
# Watching these curves evolve helps you connect quantitative performance metrics with the model’s learning dynamics.

# %%
#!python -m scripts.animate_training_curves

# %%
import glob
import os
import json
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import pandas as pd # Import pandas to read the CSV

# Define the path to the training history CSV file
history_path = "./content/best_model/training_history_resnet18.csv"

# Check if the history file exists and read it
if os.path.exists(history_path):
    # Corrected line: pass the file path to read_csv
    history_df = pd.read_csv(history_path)

    # Extract metrics from the DataFrame
    train_losses = history_df["train_loss"]
    val_losses = history_df["val_loss"]
    train_accuracies = history_df["train_acc"]
    val_accuracies = history_df["val_acc"]
    epochs = range(1, len(train_losses) + 1)

    # Check if precision and recall columns exist
    has_precision_recall = "train_precision" in history_df.columns and "val_precision" in history_df.columns and \
                           "train_recall" in history_df.columns and "val_recall" in history_df.columns

    # Adjust figure size based on whether precision/recall are available
    if has_precision_recall:
        fig, axes = plt.subplots(2, 2, figsize=(12, 8))
        ax1, ax2, ax3, ax4 = axes.flatten()
    else:
        fig, axes = plt.subplots(1, 2, figsize=(12, 5))
        ax1, ax2 = axes.flatten()
        ax3, ax4 = None, None # Set to None if not plotting precision/recall


    def animate(i):
        # Clear all relevant axes
        ax1.clear()
        ax2.clear()
        if has_precision_recall:
            ax3.clear()
            ax4.clear()

        # Plot Loss
        ax1.plot(epochs[:i+1], train_losses[:i+1], 'b-', label='Train Loss')
        ax1.plot(epochs[:i+1], val_losses[:i+1], 'r-', label='Val Loss')
        ax1.set_title("Loss Over Epochs")
        ax1.set_xlabel("Epoch")
        ax1.set_ylabel("Loss")
        ax1.legend()
        ax1.set_xlim(1, len(epochs))
        ax1.set_ylim(0, max(max(train_losses), max(val_losses)) * 1.1)

        # Plot Accuracy
        ax2.plot(epochs[:i+1], train_accuracies[:i+1], 'b-', label='Train Acc')
        ax2.plot(epochs[:i+1], val_accuracies[:i+1], 'r-', label='Val Acc')
        ax2.set_title("Accuracy Over Epochs")
        ax2.set_xlabel("Epoch")
        ax2.set_ylabel("Accuracy")
        ax2.legend()
        ax2.set_xlim(1, len(epochs))
        ax2.set_ylim(0, 1.05)

        # Plot Precision and Recall if available
        if has_precision_recall:
            train_precisions = history_df["train_precision"]
            val_precisions = history_df["val_precision"]
            train_recalls = history_df["train_recall"]
            val_recalls = history_df["val_recall"]

            ax3.plot(epochs[:i+1], train_precisions[:i+1], 'b-', label='Train Precision')
            ax3.plot(epochs[:i+1], val_precisions[:i+1], 'r-', label='Val Precision')
            ax3.set_title("Precision Over Epochs")
            ax3.set_xlabel("Epoch")
            ax3.set_ylabel("Precision")
            ax3.legend()
            ax3.set_xlim(1, len(epochs))
            ax3.set_ylim(0, 1.05)

            ax4.plot(epochs[:i+1], train_recalls[:i+1], 'b-', label='Train Recall')
            ax4.plot(epochs[:i+1], val_recalls[:i+1], 'r-', label='Val Recall')
            ax4.set_title("Recall Over Epochs")
            ax4.set_xlabel("Epoch")
            ax4.set_ylabel("Recall")
            ax4.legend()
            ax4.set_xlim(1, len(epochs))
            ax4.set_ylim(0, 1.05)


    ani = FuncAnimation(fig, animate, frames=len(epochs), interval=200, repeat=False)
    plt.close(fig) # Close the figure to prevent it from displaying as a static plot
    HTML(ani.to_jshtml())

else:
    print(f"Error: Training history file not found at {history_path}")
    print("Please ensure the training step (Section 5) has been run successfully.")

# %% [markdown]
# If you cannot see the animated training curves, maybe it is because of your browser; change it and try again!

# %% [markdown]
# ## Evaluation on Test Set
#
# This step evaluates the **best-performing trained model** on the **unseen test dataset** to measure its real-world generalization performance.
# The test set is completely isolated from training and validation, ensuring that results reflect true predictive capability rather than memorization.
#
#
# ####Process Overview
# - Loads the **best saved model checkpoint** (highest validation accuracy during training).
# - Runs inference on all test images to obtain predicted class labels.
# - Calculates standard **classification metrics** using `scikit-learn`:
#   - **Accuracy:** Overall correctness of predictions
#   - **Precision, Recall, F1-score:** Class-specific performance indicators
# - Saves both quantitative results and visual diagnostics for interpretability.
#
#
# #### Generated Outputs
# - **Classification Report:** Printed and saved to
#   `outputs/classification_report.txt`
#   → Includes per-class precision, recall, F1-score, and overall accuracy.
#
# - **Confusion Matrix:** Visualized and saved to
#   `outputs/confusion_matrix.png`
#   → Highlights which classes are most frequently confused.
#
# - **Raw Predictions:** Saved as
#   `outputs/test_predictions.csv`
#   → Contains detailed predictions for each test image.
#
#
# ####CSV File Structure
# Each row corresponds to one test image, including:
# | filename | true_label | predicted_label |
# |-----------|-------------|----------------|
# | .../lungaca1356.jpeg | lung_aca | lung_aca |
# | .../lungaca2966.jpeg | lung_aca | lung_scc |
#
# This file can be used to:
# - Identify and visualize **misclassified samples**
# - Conduct **error analysis** using pandas or Excel
# - Investigate specific class-level weaknesses or biases
#
#
# #### Why This Step Matters
# Model evaluation on an unseen test set is the **final validation** of training success.
# It quantifies how well the model generalizes to new histopathological images; a critical factor for potential clinical deployment.
# Strong, consistent results across classes indicate robust feature learning rather than dataset-specific fitting.

# %%
# --- Evaluation on Test Set ---
# This cell evaluates the trained model on the unseen test dataset.

import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns
from tqdm.auto import tqdm
from PIL import Image # Import Image for manual loading


### Configuration ###

# Define key configuration parameters for the evaluation process.
# Ensure these match the training configuration used to train the model being evaluated.
DATA_DIR = "data/lc25000_split"   # Path to the split dataset directory
MODEL_PATH = "./content/best_model/final_best_resnet18.pth" # Path to the trained model weights
OUTPUT_DIR = "outputs"            # Directory to save evaluation outputs
BATCH_SIZE = 32                   # Batch size for evaluation
MODEL_NAME = "resnet18"           # Base model architecture ('resnet18', 'resnet34', 'resnet50')
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Device to use for evaluation (GPU or CPU)

# Create output directory if needed
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"✅ Evaluation outputs will be saved to: {os.path.abspath(OUTPUT_DIR)}")


### Data Loader (Test Set) ###

# Define data transformations for the test set.
# Only resizing and normalization are applied, no augmentations.
test_tfms = transforms.Compose([
    transforms.Resize((224,224)),                      # Resize to 224x224
    transforms.ToTensor(),                             # Convert PIL Image to PyTorch Tensor
    transforms.Normalize([0.485, 0.456, 0.406],         # Normalize with ImageNet mean and std
                         [0.229, 0.224, 0.225])
])

# Custom Dataset Class (re-used from training)
class CancerDataset(Dataset):
    """
    A custom Dataset class to load images and labels from a list of file paths.
    This is used to bypass potential issues with ImageFolder and provide more control
    over data loading based on a pre-collected list of samples.
    """
    def __init__(self, data_list, transform=None):
        """
        Args:
            data_list (list): List of tuples, where each tuple is (image_path, label_index).
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.data_list = data_list # List of (image_path, label_index) tuples
        self.transform = transform

    def __len__(self):
        """Returns the total number of samples."""
        return len(self.data_list)

    def __getitem__(self, idx):
        """
        Generates one sample of data from the dataset.

        Args:
            idx (int): Index of the sample to retrieve.

        Returns:
            tuple: (image, label) where image is a Tensor and label is an integer.
        """
        img_path, label = self.data_list[idx]
        img = Image.open(img_path).convert('RGB') # Ensure 3 channels for consistency
        if self.transform:
            img = self.transform(img)
        return img, label

# Manual data collection function (re-used from training)
def collect_data_list(data_root):
    """
    Recursively scans a directory to collect image paths and assign class labels.
    Each subfolder is treated as a class.
    """
    data_list = []
    class_names = sorted([d.name for d in os.scandir(data_root) if d.is_dir()])
    class_to_idx = {cls_name: i for i, cls_name in enumerate(class_names)}

    print(f"Collecting data from: {data_root}")
    print(f"Found classes: {class_names}")

    for class_name in class_names:
        class_dir = os.path.join(data_root, class_name)
        if not os.path.isdir(class_dir):
            print(f"Warning: Directory not found for class: {class_dir}")
            continue

        for img_name in os.listdir(class_dir):
            if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
                data_list.append((os.path.join(class_dir, img_name), class_to_idx[class_name]))

    print(f"Collected {len(data_list)} images from {data_root}")
    return data_list, class_names


# Collect data lists for the test set
test_data_path = os.path.join(DATA_DIR, "test")

# Check if the test directory exists before proceeding
if os.path.exists(test_data_path):
    test_data_list, class_names = collect_data_list(test_data_path)

    if not test_data_list:
        print("Error: No images found in the test directory after collection.")
    else:
        # Create custom dataset and DataLoader for the test set
        test_ds   = CancerDataset(test_data_list, transform=test_tfms)
        test_dl   = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0) # No shuffling for evaluation

        print(f"Test dataset size: {len(test_ds)}")
        print(f"Class names: {class_names}")


        ### Model Setup ###

        # Initialize the model architecture (should match the trained model)
        num_classes = len(class_names)
        model_fn = getattr(models, MODEL_NAME) # Get the model constructor from torchvision.models
        model = model_fn(pretrained=False)    # Do NOT load pretrained weights here, we load our trained weights
        # Replace the final fully connected layer to match the number of classes
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        model = model.to(DEVICE)              # Move model to the specified device (GPU/CPU)

        # Load the trained model weights
        if os.path.exists(MODEL_PATH):
            print(f"Attempting to load model from: {os.path.abspath(MODEL_PATH)}")
            try:
                model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
                print("✅ Model weights loaded successfully.")
            except Exception as e:
                print(f"❌ Error loading model weights: {e}")
                print("Please ensure the MODEL_PATH is correct and the model architecture matches the saved weights.")
                # Exit or handle the error appropriately if model cannot be loaded
                exit() # Exit the script if model loading fails
        else:
            print(f"❌ Error: Trained model not found at {os.path.abspath(MODEL_PATH)}")
            print("Please ensure the training step (Section 5) has been run successfully and the model was saved.")
            exit() # Exit the script if model file is not found

        # Set model to evaluation mode
        model.eval()


        ### Evaluation Loop ###

        # Lists to store true labels, predicted labels, and prediction confidences
        all_labels = []
        all_preds = []
        all_probs = [] # Store probabilities for confidence

        print("\nEvaluating on test set...")
        # Disable gradient calculation for evaluation
        with torch.no_grad():
            # Iterate over batches in the test dataloader
            for inputs, labels in tqdm(test_dl, desc="Evaluating Batches"):
                # Move data to the specified device
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

                # Forward pass
                outputs = model(inputs)
                # Get predicted class indices
                _, preds = torch.max(outputs, 1)
                # Get probabilities (softmax outputs)
                probs = torch.softmax(outputs, dim=1)
                # Get confidence of the predicted class
                confidences = torch.max(probs, 1).values

                # Append batch results to lists
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(preds.cpu().numpy())
                all_probs.extend(confidences.cpu().numpy())


        # Convert lists to numpy arrays for metric calculations
        all_labels = np.array(all_labels)
        all_preds = np.array(all_preds)
        all_probs = np.array(all_probs)


        ### Calculate & Save Metrics ###

        print("\nCalculating metrics...")

        # Generate Classification Report
        report = classification_report(all_labels, all_preds, target_names=class_names)
        print("\nClassification Report:")
        print(report)

        # Save Classification Report to a file
        report_path = os.path.join(OUTPUT_DIR, "classification_report.txt")
        with open(report_path, "w") as f:
            f.write(report)
        print(f"✅ Classification report saved to: {os.path.abspath(report_path)}")

        # Generate Confusion Matrix
        cm = confusion_matrix(all_labels, all_preds)
        print("\nConfusion Matrix:")
        print(cm)

        # Plot and Save Confusion Matrix
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
        plt.title("Confusion Matrix")
        plt.xlabel("Predicted Label")
        plt.ylabel("True Label")
        plt.tight_layout()
        cm_path = os.path.join(OUTPUT_DIR, "confusion_matrix.png")
        plt.savefig(cm_path)
        print(f"✅ Confusion matrix plot saved to: {os.path.abspath(cm_path)}")
        plt.show()


        ### Save Predictions CSV ###

        print("\nSaving predictions...")

        # Create a DataFrame with filenames, true labels, predicted labels, and confidence
        # We need the original filenames from the data_list
        filenames = [item[0] for item in test_data_list]
        # Map predicted indices back to class names
        predicted_class_names = [class_names[pred_idx] for pred_idx in all_preds]
        # Map true indices back to class names
        true_class_names = [class_names[label_idx] for label_idx in all_labels]

        predictions_df = pd.DataFrame({
            "filename": filenames,
            "true_label": true_class_names,
            "predicted_label": predicted_class_names,
            "confidence": all_probs
        })

        # Save the DataFrame to a CSV file
        predictions_path = os.path.join(OUTPUT_DIR, "test_predictions.csv")
        predictions_df.to_csv(predictions_path, index=False)
        print(f"✅ Test predictions saved to: {os.path.abspath(predictions_path)}")

else:
    print(f"Error: Test data directory not found at {test_data_path}")
    print("Please ensure the data splitting step completed successfully and the data is in the expected structure.")
# Out:
# ✅ Evaluation outputs will be saved to: /content/outputs
# ...
# Found classes: ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']
# Collected 3750 images from data/lc25000_split/test
# Test dataset size: 3750
# Class names: ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']
# Attempting to load model from: /content/content/best_model/final_best_resnet18.pth
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ✅ Model weights loaded successfully.
#
# Evaluating on test set...
# ...

# %% [markdown]
# ## Grad-CAM Visualization
#
# This section applies **Gradient-weighted Class Activation Mapping (Grad-CAM)** to interpret how the trained model makes its predictions.
# Grad-CAM highlights the regions of an image that contribute most to the model’s decision, allowing for visual insight into what the network “sees” as diagnostically relevant.
#
#
# ####Process Overview
# 1. **Model Initialization:**
#    Loads the best-trained model (`ResNet18`) and restores its weights from
#    `./content/best_model/final_best_resnet18.pth`.
#
# 2. **Target Layer Selection:**
#    Automatically identifies the **last convolutional layer** in the model,
#    which captures the spatial features most relevant for class discrimination.
#
# 3. **Hooks Registration:**
#    Registers forward and backward hooks to record **feature activations** and **gradients**
#    during a forward and backward pass.
#
# 4. **Image Sampling and Preprocessing:**
#    - Randomly selects a test image from `data/lc25000_split/test/`.
#    - Resizes and normalizes the image using the same preprocessing as training.
#    - Converts it to a tensor and sends it to the GPU (if available).
#
# 5. **Grad-CAM Computation:**
#    - Performs a forward pass to obtain the model’s predicted class.
#    - Computes the gradient of that class score with respect to the feature maps.
#    - Applies **global average pooling** to the gradients to obtain per-channel weights.
#    - Multiplies the weights with feature activations and sums across channels to generate the **class activation map (CAM)**.
#    - Applies **ReLU** and rescales the heatmap to match the original image dimensions.
#
# 6. **Visualization and Overlay:**
#    - Converts the heatmap into a color map (Jet colormap).
#    - Overlays it on the original image with adjustable transparency to highlight salient regions.
#    - Displays side-by-side **Original Image** and **Grad-CAM Overlay** for comparison.
#    - Saves the final visualization to the `results/` directory.
#
#
# ####Outputs
# - **Grad-CAM Heatmap:** Overlaid visualization showing model attention areas, saved as
#   `results/gradcam_<image_name>_predicted_<class>.png`
# - **Console Output:** Displays the image name, predicted class, and true label (if available).
#
#
# ####This Step:
# ,Grad-CAM, adds **interpretability** to deep learning models — especially important in medical imaging:
# - Helps verify that the model focuses on **clinically meaningful tissue regions** rather than artifacts.
# - Builds **trust** in automated diagnostic systems by offering transparent visual explanations.
# - Useful for debugging model behavior and identifying potential sources of misclassification.
#
#
# #### Conceptual Insight
# In CNNs, deeper layers capture increasingly complex features.
# Grad-CAM leverages the **gradients of the target class** flowing into the final convolutional layer to produce a coarse localization map of important image regions.
# Brighter (red/yellow) areas indicate stronger influence on the model’s decision, whereas cooler (blue) areas contribute less.

# %%
# --- Grad-CAM Visualization ---
# This cell generates and visualizes a Grad-CAM heatmap for a sample test image
# to show which parts of the image the model is focusing on for its prediction.

import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2 # Import OpenCV for image processing
import random # Import random to pick an image


### Configuration ###

# Define key configuration parameters for Grad-CAM.
# Ensure these match the training configuration used to train the model being evaluated.
MODEL_PATH = "./content/best_model/final_best_resnet18.pth" # Path to the trained model weights
OUTPUT_DIR = "results" # Directory to save the Grad-CAM heatmap - Changed from "outputs" to "results"
MODEL_NAME = "resnet18" # Base model architecture ('resnet18', 'resnet34', 'resnet50')
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Device to use (GPU or CPU)

# Create output directory if needed
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"✅ Grad-CAM output will be saved to: {os.path.abspath(OUTPUT_DIR)}")


### Model Setup ###

# Initialize the model architecture (should match the trained model)
# We need to determine the number of classes from the data structure
data_root_test = "data/lc25000_split/test"
if os.path.exists(data_root_test):
    class_names = sorted([d.name for d in os.scandir(data_root_test) if d.is_dir()])
    num_classes = len(class_names)
    if not class_names:
         print(f"Error: No class directories found in {data_root_test}")
         exit() # Exit if no classes found
else:
    print(f"Error: Test data directory not found at {data_root_test}")
    exit() # Exit if test data directory not found


model_fn = getattr(models, MODEL_NAME) # Get the model constructor from torchvision.models
model = model_fn(pretrained=False)    # Do NOT load pretrained weights here
model.fc = nn.Linear(model.fc.in_features, num_classes) # Replace final layer
model = model.to(DEVICE)              # Move model to the specified device

# Load the trained model weights
if os.path.exists(MODEL_PATH):
    print(f"Attempting to load model from: {os.path.abspath(MODEL_PATH)}")
    try:
        model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
        print("✅ Model weights loaded successfully.")
    except Exception as e:
        print(f"❌ Error loading model weights: {e}")
        print("Please ensure the MODEL_PATH is correct and the model architecture matches the saved weights.")
        exit() # Exit the script if model loading fails
else:
    print(f"❌ Error: Trained model not found at {os.path.abspath(MODEL_PATH)}")
    print("Please ensure the training step (Section 5) has been run successfully and the model was saved.")
    exit() # Exit the script if model file is not found

# Set model to evaluation mode
model.eval()


### Grad-CAM Implementation ###

# Function to get the last convolutional layer of the model
def get_last_conv_layer(model):
    """
    Finds the last convolutional layer in a PyTorch model.
    Handles common architectures like ResNet.
    """
    last_layer = None
    for name, module in model.named_modules():
        if isinstance(module, nn.Conv2d):
            last_layer = module
    return last_layer

# Get the target layer for Grad-CAM (the last convolutional layer)
target_layer = get_last_conv_layer(model)
if target_layer is None:
    print("Error: Could not find a convolutional layer in the model for Grad-CAM.")
    exit()

# Store gradients and activations
gradients = None
activations = None

# Hook function to record gradients
def backward_hook(module, grad_input, grad_output):
    global gradients
    gradients = grad_output[0]

# Hook function to record activations
def forward_hook(module, input, output):
    global activations
    activations = output

# Register hooks to the target layer
backward_hook_handle = target_layer.register_backward_hook(backward_hook)
forward_hook_handle = target_layer.register_forward_hook(forward_hook)


### Image Loading and Preprocessing ###

# Define image transformations for Grad-CAM (resize and normalize)
gradcam_tfms = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# Dynamically select an image path from the test set
IMAGE_PATH = None
if 'test_data_list' in locals() and test_data_list:
    # Pick a random image from the test_data_list
    IMAGE_PATH = random.choice(test_data_list)[0]
    print(f"Selected random image from test set: {IMAGE_PATH}")
elif os.path.exists(data_root_test):
     # If test_data_list is not available, try to find any image in the test directory
     for root, _, files in os.walk(data_root_test):
         for file in files:
             if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
                 IMAGE_PATH = os.path.join(root, file)
                 print(f"Found and selected image from test directory: {IMAGE_PATH}")
                 break # Found one, break the loops
         if IMAGE_PATH:
             break # Found one, break the outer loop

# Load the image and create input tensor
image = None
input_tensor = None
if IMAGE_PATH and os.path.exists(IMAGE_PATH):
    try:
        image = Image.open(IMAGE_PATH).convert('RGB')
        input_tensor = gradcam_tfms(image).unsqueeze(0).to(DEVICE) # Add batch dimension and move to device
    except Exception as e:
        print(f"Error loading or processing image {IMAGE_PATH}: {e}")
else:
    print("Error: No valid image path found or image not found at the selected path.")


### Generate Grad-CAM (only if image loaded successfully) ###

if input_tensor is not None:
    # Perform forward pass
    outputs = model(input_tensor)
    # Get the predicted class
    _, predicted_class = torch.max(outputs, 1)

    # Calculate the gradient of the predicted class score with respect to the target layer output
    model.zero_grad() # Clear existing gradients
    # Create a tensor of ones for the predicted class score
    one_hot_output = torch.zeros_like(outputs)
    one_hot_output[0, predicted_class[0]] = 1
    outputs.backward(gradient=one_hot_output, retain_graph=True) # Backward pass to get gradients

    # Get gradients and activations (should be populated by hooks)
    # Ensure gradients and activations are on the CPU for numpy operations
    gradients = gradients.cpu().data.numpy()[0]
    activations = activations.cpu().data.numpy()[0]

    # Detach hooks after use
    backward_hook_handle.remove()
    forward_hook_handle.remove()

    # Compute the weights (global average pooling of gradients)
    weights = np.mean(gradients, axis=(1, 2)) # Shape: (num_channels,)

    # Compute the Grad-CAM heatmap
    # Element-wise multiply weights and activations, then sum over channels
    cam = np.sum(weights[:, np.newaxis, np.newaxis] * activations, axis=0) # Shape: (height, width)

    # Apply ReLU to the heatmap (only positive contributions)
    cam = np.maximum(cam, 0)

    # Resize the heatmap to the original image size
    image_width, image_height = image.size
    cam = cv2.resize(cam, (image_width, image_height))

    # Normalize the heatmap
    cam = (cam - cam.min()) / (cam.max() - cam.min())

    # Convert heatmap to a color map
    heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)
    # Convert original image to numpy array (ensure RGB)
    original_image_np = np.array(image.convert('RGB'))
    # Combine original image and heatmap (overlay)
    # Use a weighting factor (e.g., 0.4) to control heatmap intensity
    overlay_image = cv2.addWeighted(original_image_np, 0.6, heatmap, 0.4, 0)

    # Convert the combined image back to PIL format for displaying or saving
    overlay_image_pil = Image.fromarray(cv2.cvtColor(overlay_image, cv2.COLOR_BGR2RGB))


    ### Display and Save Results ###

    # Get the predicted class name
    predicted_class_name = class_names[predicted_class.item()]
    true_label = "Unknown" # We don't have true label easily here without test_predictions.csv

    # Try to get the true label from the test_data_list if available
    # Note: This requires test_data_list to be available in the current scope,
    # which it is if the previous evaluation cell was run.
    if 'test_data_list' in locals():
        try:
            # Find the corresponding entry in test_data_list by image path
            img_entry = next((item for item in test_data_list if os.path.abspath(item[0]) == os.path.abspath(IMAGE_PATH)), None)
            if img_entry:
                true_label = class_names[img_entry[1]]
        except Exception as e:
            print(f"Warning: Could not find true label for {IMAGE_PATH}: {e}")


    print(f"Image: {os.path.basename(IMAGE_PATH)}")
    print(f"Predicted Class: {predicted_class_name}")
    if true_label != "Unknown":
         print(f"True Label: {true_label}")


    # Display the original image and the Grad-CAM overlay
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.title("Original Image")
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(overlay_image_pil)
    plt.title(f"Grad-CAM Overlay (Predicted: {predicted_class_name})")
    plt.axis('off')

    plt.tight_layout()
    plt.show()

    # Save the Grad-CAM overlay image
    # Construct a safe filename
    image_base_name = os.path.splitext(os.path.basename(IMAGE_PATH))[0]
    output_filename = f"gradcam_{image_base_name}_predicted_{predicted_class_name}.png"
    output_path = os.path.join(OUTPUT_DIR, output_filename)

    overlay_image_pil.save(output_path)
    print(f"✅ Grad-CAM overlay image saved to: {os.path.abspath(output_path)}")

else:
    print("Grad-CAM could not be generated because the image was not loaded successfully.")
# Out:
# ✅ Grad-CAM output will be saved to: /content/results
# Attempting to load model from: /content/content/best_model/final_best_resnet18.pth
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ✅ Model weights loaded successfully.
# Selected random image from test set: data/lc25000_split/test/lung_n/lungn3342.jpeg
# ...

# %% [markdown]
# ## Visualize Predictions as an Image Grid
#
# This section presents a **grid of test images** with their corresponding **true labels** and **model predictions**, using data from `results/test_predictions.csv` generated in the evaluation step.
# Each image is annotated with a color-coded title to quickly distinguish correct predictions from misclassifications.
#
#
# ####Visualization Overview
# - **Green titles:** Correct predictions — the model’s prediction matches the true class.
# - **Red titles:** Misclassifications — the model’s prediction differs from the ground truth.
# - The grid provides a balanced mix of correctly and incorrectly classified samples to visually assess the model’s performance.
# - The final grid is automatically saved as:
#   `results/prediction_grid.png`
#
#
# ####Purpose and Insight
# This visualization bridges quantitative results (accuracy, precision, F1-score) with qualitative understanding.
# It allows you to:
# - Quickly **validate prediction consistency** across different cancer subtypes.
# - Observe **visual patterns** in both correct and incorrect classifications.
# - Detect cases where misclassifications occur between **visually similar tissue types**, such as lung adenocarcinoma vs. squamous carcinoma.
#
# By directly observing the model’s predictions on real histopathology images, you can assess whether the network focuses on meaningful diagnostic features rather than artifacts.
#
#
# ####Configuration
# - The display grid size can be controlled via:
#   - `N_IMAGES`: Number of test samples to display.
#   - `COLS`: Number of columns in the grid.
# - Images are **randomly sampled** from the test prediction file each run, providing diverse visualization sets.
#
#
# #### This Step:
# - Enhances interpretability by turning numeric metrics into **visual evidence** of model behavior.
# - Helps identify **systematic misclassifications** or class confusion patterns.
# - Offers a more intuitive understanding of **model confidence and bias** across tissue types.

# %%
# --- Visualize Predictions as an Image Grid ---
# This cell displays a random sample of test images in a grid, showing their true and predicted labels.

import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os
import random


### Configuration ###

# Define key configuration parameters for visualization.
PREDICTIONS_CSV = "outputs/test_predictions.csv" # Path to the test predictions CSV file
OUTPUT_DIR = "results"                       # Directory to save the output grid image
N_IMAGES = 9                                 # Number of images to display in the grid
COLS = 3                                     # Number of columns in the grid

# Create output directory if needed
os.makedirs(OUTPUT_DIR, exist_ok=True)


### Load Predictions ###

predictions_df = None
if os.path.exists(PREDICTIONS_CSV):
    predictions_df = pd.read_csv(PREDICTIONS_CSV)
    print(f"✅ Loaded predictions from: {os.path.abspath(PREDICTIONS_CSV)}")
else:
    print(f"Error: Predictions CSV not found at {PREDICTIONS_CSV}")
    print("Please ensure the evaluation step (Section 8) has been run successfully.")


### Visualize Predictions ###

if predictions_df is not None and not predictions_df.empty:
    # Sample N_IMAGES randomly from the predictions
    if len(predictions_df) >= N_IMAGES:
        sample_df = predictions_df.sample(n=N_IMAGES, random_state=42) # Use random_state for reproducibility
    else:
        print(f"Warning: Only {len(predictions_df)} predictions available, displaying all.")
        sample_df = predictions_df

    # Determine the number of rows needed for the grid
    rows = (len(sample_df) + COLS - 1) // COLS

    # Create the figure and axes for the grid
    fig, axes = plt.subplots(rows, COLS, figsize=(COLS * 3, rows * 3))
    # Flatten the axes array for easy iteration
    axes = axes.flatten()

    # Iterate through the sampled predictions and display images
    for i, (index, row) in enumerate(sample_df.iterrows()):
        img_path = row['filename']
        true_label = row['true_label']
        predicted_label = row['predicted_label']

        # Determine title color based on correctness
        title_color = "green" if true_label == predicted_label else "red"

        # Load and display the image
        if os.path.exists(img_path):
            try:
                img = Image.open(img_path)
                axes[i].imshow(img)
                axes[i].set_title(f"True: {true_label}\nPred: {predicted_label}", color=title_color)
                axes[i].axis("off") # Turn off axes
            except Exception as e:
                print(f"Error loading image {img_path}: {e}")
                axes[i].set_title("Image Load Error", color="red")
                axes[i].axis("off")
        else:
             axes[i].set_title("Image Not Found", color="red")
             axes[i].axis("off")
             print(f"Warning: Image file not found at {img_path}")


    # Hide any unused subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout() # Adjust layout to prevent titles overlapping

    # Save the grid image
    output_path = os.path.join(OUTPUT_DIR, "prediction_grid.png")
    plt.savefig(output_path)
    print(f"✅ Prediction grid image saved to: {os.path.abspath(output_path)}")

    plt.show()

elif predictions_df is not None:
    print("No predictions available to display.")
else:
    print("Cannot visualize predictions because the predictions CSV was not loaded.")
# Out:
# ✅ Loaded predictions from: /content/outputs/test_predictions.csv
# ✅ Prediction grid image saved to: /content/results/prediction_grid.png

# %% [markdown]
# ##Visualize Misclassifications
#
# This section highlights all **misclassified test images** — cases where the model’s predicted label does **not** match the true label.
# Each image is displayed in a grid with red titles showing both the **true** and **predicted** classes.
# The grid provides a visual diagnostic tool for understanding the types of errors made by the trained model.
#
#
# #### Purpose
# - Focuses analysis on the **failure cases** of the model.
# - Reveals **patterns of confusion** between visually similar cancer subtypes (e.g., *lung_aca* vs. *lung_scc*).
# - Helps detect potential issues such as:
#   - Ambiguous tissue samples
#   - Poor staining or low image quality
#   - Data imbalance leading to class bias
#   - Overfitting on certain visual patterns
#
# The visualization is automatically saved to:
# `results/misclassified_grid.png`
#
#
# #### Configuration
# - The number of displayed misclassified images and grid layout can be customized using:
#   - `--n_images`: number of samples to visualize.
#   - `--cols`: number of columns in the grid.
# - Only samples with incorrect predictions (where `true_label ≠ predicted_label`) are included.
# - Data is loaded from `results/test_predictions.csv`, generated during model evaluation.
#
#
# ####This Step:
# While high accuracy is important, **understanding model errors** is essential for true reliability; especially in medical imaging.
# By analyzing misclassified samples, you can:
# - Identify **systematic weaknesses** in model generalization.
# - Detect classes that are **visually similar** and prone to confusion.
# - Form hypotheses for **data augmentation** or **model architecture improvements**.
#
# This type of visual analysis bridges the gap between metrics and intuition, helping validate whether the model’s failures are reasonable or concerning.

# %%
# --- Visualize Misclassifications ---
# This cell displays a grid of misclassified test images.

import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os
import random


### Configuration ###

# Define key configuration parameters for visualization.
PREDICTIONS_CSV = "outputs/test_predictions.csv" # Path to the test predictions CSV file
OUTPUT_DIR = "results"                       # Directory to save the output grid image
N_IMAGES = 9                                 # Number of images to display in the grid
COLS = 3                                     # Number of columns in the grid

# Create output directory if needed
os.makedirs(OUTPUT_DIR, exist_ok=True)

### Load Predictions and Filter Misclassifications ###

misclassified_df = None
if os.path.exists(PREDICTIONS_CSV):
    predictions_df = pd.read_csv(PREDICTIONS_CSV)
    print(f"✅ Loaded predictions from: {os.path.abspath(PREDICTIONS_CSV)}")

    # Filter for misclassified images
    misclassified_df = predictions_df[predictions_df['true_label'] != predictions_df['predicted_label']]
    print(f"✅ Found {len(misclassified_df)} misclassified images.")

else:
    print(f"Error: Predictions CSV not found at {PREDICTIONS_CSV}")
    print("Please ensure the evaluation step (Section 8) has been run successfully.")


### Visualize Misclassifications ###

if misclassified_df is not None and not misclassified_df.empty:
    # Sample N_IMAGES randomly from the misclassified predictions
    if len(misclassified_df) >= N_IMAGES:
        sample_df = misclassified_df.sample(n=N_IMAGES, random_state=42) # Use random_state for reproducibility
    else:
        print(f"Warning: Only {len(misclassified_df)} misclassified images available, displaying all.")
        sample_df = misclassified_df

    # Determine the number of rows needed for the grid
    rows = (len(sample_df) + COLS - 1) // COLS

    # Create the figure and axes for the grid
    fig, axes = plt.subplots(rows, COLS, figsize=(COLS * 3, rows * 3))
    # Flatten the axes array for easy iteration
    axes = axes.flatten()

    # Iterate through the sampled misclassifications and display images
    for i, (index, row) in enumerate(sample_df.iterrows()):
        img_path = row['filename']
        true_label = row['true_label']
        predicted_label = row['predicted_label']

        # Title color is always red for misclassifications
        title_color = "red"

        # Load and display the image
        if os.path.exists(img_path):
            try:
                img = Image.open(img_path)
                axes[i].imshow(img)
                axes[i].set_title(f"True: {true_label}\nPred: {predicted_label}", color=title_color)
                axes[i].axis("off") # Turn off axes
            except Exception as e:
                print(f"Error loading image {img_path}: {e}")
                axes[i].set_title("Image Load Error", color="red")
                axes[i].axis("off")
        else:
             axes[i].set_title("Image Not Found", color="red")
             axes[i].axis("off")
             print(f"Warning: Image file not found at {img_path}")


    # Hide any unused subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout() # Adjust layout to prevent titles overlapping

    # Save the grid image
    output_path = os.path.join(OUTPUT_DIR, "misclassified_grid.png")
    plt.savefig(output_path)
    print(f"✅ Misclassified grid image saved to: {os.path.abspath(output_path)}")

    plt.show()

elif misclassified_df is not None:
    print("No misclassified images available to display.")
else:
    print("Cannot visualize misclassifications because the predictions CSV was not loaded.")
# Out:
# ✅ Loaded predictions from: /content/outputs/test_predictions.csv
# ✅ Found 1 misclassified images.
# ...
# ✅ Misclassified grid image saved to: /content/results/misclassified_grid.png

# %% [markdown]
# ##Visualize Grad-CAM Heatmaps in a Grid
#
# This section presents a **grid of test images** alongside their **Grad-CAM heatmap overlays**, allowing side-by-side comparison between the original histopathology image and the regions the model focused on when making its prediction.
# The visualization helps bridge quantitative performance metrics with **qualitative model interpretability**.
#
#
# #### Purpose
# - Provides a holistic view of **where** the trained model (e.g., ResNet18) is focusing its attention during inference.
# - Combines **original images** and their **Grad-CAM overlays** in a single grid for visual comparison.
# - Supports both:
#   - **All test samples**, or
#   - **Only misclassified samples**, for focused error interpretation.
# - The final visualization is saved automatically as:
#   `results/gradcam_grid.png`
#
#
# #### Configuration
# - **`N_IMAGES`** – Number of test samples to visualize.
# - **`ONLY_MISCLASSIFIED`** – Boolean flag to display only incorrect predictions.
# - Each row contains:
#   - The **original image** (left)
#   - The **Grad-CAM heatmap overlay** (right)
# - Titles indicate predicted labels:
#   - 🟩 **Green:** Correct prediction
#   - 🟥 **Red:** Misclassification
#
#
# #### This Step:
# While single-image Grad-CAMs (Section 9) show localized attention, grid-based Grad-CAMs reveal **aggregate interpretability patterns** across multiple predictions.
# This helps you:
# - Assess if the model consistently attends to **diagnostically relevant tissue regions**.
# - Identify cases where the model fixates on **irrelevant artifacts** or **background regions**.
# - Understand the **failure modes** of the model by comparing misclassified and correctly classified examples side by side.
#
# By visualizing multiple examples together, you gain insight into both **the reliability** and **the reasoning consistency** of your deep learning model.

# %%
# --- Visualize Grad-CAM Heatmaps in a Grid ---
# This cell displays a grid of test images (optionally only misclassified ones)
# with their Grad-CAM heatmaps side by side.

import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2 # Import OpenCV for image processing
import pandas as pd
import random


### Configuration ###

# Define key configuration parameters for Grad-CAM grid visualization.
PREDICTIONS_CSV = "outputs/test_predictions.csv"  # Path to the test predictions CSV file
MODEL_PATH = "./content/best_model/final_best_resnet18.pth" # Path to the trained model weights
OUTPUT_DIR = "results"                            # Directory to save the output grid image
MODEL_NAME = "resnet18"                           # Base model architecture ('resnet18', 'resnet34', 'resnet50')
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Device to use (GPU or CPU)
N_IMAGES = 4                                      # Number of images to display in the grid (original + heatmap)
COLS = 2                                          # Number of columns in the grid (original and heatmap)
ONLY_MISCLASSIFIED = True                         # Set to True to only show misclassified images

# Create output directory if needed
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"✅ Grad-CAM grid output will be saved to: {os.path.abspath(OUTPUT_DIR)}")


### Load Predictions and Filter Images ###

predictions_df = None
if os.path.exists(PREDICTIONS_CSV):
    predictions_df = pd.read_csv(PREDICTIONS_CSV)
    print(f"✅ Loaded predictions from: {os.path.abspath(PREDICTIONS_CSV)}")

    if ONLY_MISCLASSIFIED:
        filtered_df = predictions_df[predictions_df['true_label'] != predictions_df['predicted_label']]
        print(f"✅ Found {len(filtered_df)} misclassified images.")
        if filtered_df.empty:
            print("No misclassified images found to display Grad-CAM for.")
            filtered_df = None # Set to None if no misclassified images
    else:
        filtered_df = predictions_df
        print(f"✅ Using {len(filtered_df)} total images for Grad-CAM grid.")


    # Sample N_IMAGES from the filtered predictions
    sample_df = None
    if filtered_df is not None and not filtered_df.empty:
        if len(filtered_df) >= N_IMAGES:
            sample_df = filtered_df.sample(n=N_IMAGES, random_state=42) # Use random_state for reproducibility
        else:
            print(f"Warning: Only {len(filtered_df)} images available, displaying all.")
            sample_df = filtered_df

else:
    print(f"Error: Predictions CSV not found at {PREDICTIONS_CSV}")
    print("Please ensure the evaluation step (Section 8) has been run successfully.")


### Model Setup ###

# Initialize the model architecture (should match the trained model)
# We need to determine the number of classes from the data structure
data_root_test = "data/lc25000_split/test"
class_names = []
if os.path.exists(data_root_test):
    class_names = sorted([d.name for d in os.scandir(data_root_test) if d.is_dir()])
    num_classes = len(class_names)
    if not class_names:
         print(f"Error: No class directories found in {data_root_test}")
else:
    print(f"Error: Test data directory not found at {data_root_test}")
    # If data_root_test not found, try to get class names from predictions_df if available
    if predictions_df is not None and not predictions_df.empty:
         class_names = sorted(predictions_df['true_label'].unique())
         num_classes = len(class_names)
         print(f"Attempting to get class names from predictions CSV: {class_names}")
    else:
         print("Cannot determine number of classes. Exiting.")
         exit()


if num_classes == 0:
    print("Error: Number of classes could not be determined. Exiting.")
    exit()


model_fn = getattr(models, MODEL_NAME) # Get the model constructor from torchvision.models
model = model_fn(pretrained=False)    # Do NOT load pretrained weights here
model.fc = nn.Linear(model.fc.in_features, num_classes) # Replace final layer
model = model.to(DEVICE)              # Move model to the specified device

# Load the trained model weights
if os.path.exists(MODEL_PATH):
    print(f"Attempting to load model from: {os.path.abspath(MODEL_PATH)}")
    try:
        model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
        print("✅ Model weights loaded successfully.")
    except Exception as e:
        print(f"❌ Error loading model weights: {e}")
        print("Please ensure the MODEL_PATH is correct and the model architecture matches the saved weights.")
        exit() # Exit the script if model loading fails
else:
    print(f"❌ Error: Trained model not found at {os.path.abspath(MODEL_PATH)}")
    print("Please ensure the training step (Section 5) has been run successfully and the model was saved.")
    exit() # Exit the script if model file is not found

# Set model to evaluation mode
model.eval()


### Grad-CAM Implementation ###

# Function to get the last convolutional layer of the model
def get_last_conv_layer(model):
    """
    Finds the last convolutional layer in a PyTorch model.
    Handles common architectures like ResNet.
    """
    last_layer = None
    for name, module in model.named_modules():
        if isinstance(module, nn.Conv2d):
            last_layer = module
    # Fallback for some models or structures if direct Conv2d not found in named_modules
    if last_layer is None and hasattr(model, 'layer4'): # Specific to ResNet-like structures
         if isinstance(model.layer4, nn.Sequential):
              for sub_module in reversed(model.layer4):
                   for name, module in sub_module.named_modules():
                        if isinstance(module, nn.Conv2d):
                             last_layer = module
                             break
                   if last_layer: break
         elif isinstance(model.layer4, nn.Module): # Handle case where layer4 might be a single module
              for name, module in model.layer4.named_modules():
                   if isinstance(module, nn.Conv2d):
                        last_layer = module
                        break

    if last_layer is None:
         print("Warning: Could not find a standard last convolutional layer. Attempting alternative.")
         # More general fallback - traverse all modules
         for name, module in reversed(list(model.named_modules())):
              if isinstance(module, nn.Conv2d):
                   last_layer = module
                   print(f"Using alternative last conv layer: {name}")
                   break


    return last_layer


# Get the target layer for Grad-CAM (the last convolutional layer)
target_layer = get_last_conv_layer(model)
if target_layer is None:
    print("Error: Could not find a convolutional layer in the model for Grad-CAM. Cannot proceed.")
    #exit() # Don't exit immediately, allow message to be displayed


# Store gradients and activations
gradients = {}
activations = {}

# Hook function to record gradients
def backward_hook(module, grad_input, grad_output):
    gradients['value'] = grad_output[0]

# Hook function to record activations
def forward_hook(module, input, output):
    activations['value'] = output

# Register hooks to the target layer (only if target_layer was found)
backward_hook_handle = None
forward_hook_handle = None
if target_layer:
     backward_hook_handle = target_layer.register_backward_hook(backward_hook)
     forward_hook_handle = target_layer.register_forward_hook(forward_hook)
else:
     print("Skipping Grad-CAM generation due to missing target layer.")


# Define image transformations for Grad-CAM (resize and normalize)
gradcam_tfms = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])


# Function to generate Grad-CAM heatmap for a single image
def generate_gradcam(image_path, model, target_layer, class_names, device):
    """Generates and returns the Grad-CAM overlay image for a single image file."""
    try:
        # Load and preprocess the image
        image = Image.open(image_path).convert('RGB')
        input_tensor = gradcam_tfms(image).unsqueeze(0).to(device)

        # Perform forward pass
        outputs = model(input_tensor)
        _, predicted_class = torch.max(outputs, 1)

        # Calculate the gradient of the predicted class score
        model.zero_grad()
        one_hot_output = torch.zeros_like(outputs).to(device)
        one_hot_output[0, predicted_class[0]] = 1
        outputs.backward(gradient=one_hot_output, retain_graph=True)

        # Get gradients and activations
        # Ensure hooks populated the dictionaries before accessing
        if 'value' not in gradients or 'value' not in activations:
             print(f"Error: Gradients or activations not captured for {image_path}. Skipping Grad-CAM.")
             return None, None # Return None for image and predicted class

        grads = gradients['value'].cpu().data.numpy()[0]
        acts = activations['value'].cpu().data.numpy()[0]

        # Compute Grad-CAM
        weights = np.mean(grads, axis=(1, 2))
        cam = np.sum(weights[:, np.newaxis, np.newaxis] * acts, axis=0)
        cam = np.maximum(cam, 0)

        # Resize and normalize heatmap
        image_width, image_height = image.size
        cam = cv2.resize(cam, (image_width, image_height))
        cam = (cam - cam.min()) / (cam.max() - cam.min()) if cam.max() > cam.min() else cam * 0 # Avoid division by zero

        # Create heatmap overlay
        heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)
        original_image_np = np.array(image.convert('RGB'))
        overlay_image = cv2.addWeighted(original_image_np, 0.6, heatmap, 0.4, 0)
        overlay_image_pil = Image.fromarray(cv2.cvtColor(overlay_image, cv2.COLOR_BGR2RGB))

        predicted_class_name = class_names[predicted_class.item()]
        return overlay_image_pil, predicted_class_name

    except Exception as e:
        print(f"Error generating Grad-CAM for {image_path}: {e}")
        return None, None


### Visualize Grad-CAM Grid ###

if sample_df is not None and not sample_df.empty and target_layer:
    rows = len(sample_df) # One row per image in the sample
    fig, axes = plt.subplots(rows, COLS, figsize=(COLS * 4, rows * 4)) # Adjust figure size
    axes = axes.flatten()

    print("\nGenerating Grad-CAM grid...")

    # Iterate through sampled images and generate/display Grad-CAM
    for i, (index, row) in enumerate(sample_df.iterrows()):
        img_path = row['filename']
        true_label = row['true_label']
        predicted_label = row['predicted_label']

        # Generate Grad-CAM for the image
        gradcam_overlay, predicted_name = generate_gradcam(img_path, model, target_layer, class_names, DEVICE)

        if gradcam_overlay is not None:
            # Display original image
            try:
                original_image = Image.open(img_path)
                axes[i * COLS].imshow(original_image)
                axes[i * COLS].set_title(f"Original\nTrue: {true_label}", color="black") # Original title black
                axes[i * COLS].axis("off")
            except Exception as e:
                 print(f"Error loading original image {img_path} for display: {e}")
                 axes[i * COLS].set_title("Original Image Load Error")
                 axes[i * COLS].axis("off")


            # Display Grad-CAM overlay
            axes[i * COLS + 1].imshow(gradcam_overlay)
            # Set title color based on correctness
            title_color = "green" if true_label == predicted_label else "red"
            axes[i * COLS + 1].set_title(f"Grad-CAM Overlay\nPred: {predicted_name}", color=title_color)
            axes[i * COLS + 1].axis("off")
        else:
            # If Grad-CAM failed, display placeholders
            axes[i * COLS].set_title("Original Image\n(Failed to load/process)", color="red")
            axes[i * COLS].axis("off")
            axes[i * COLS + 1].set_title("Grad-CAM\n(Failed to generate)", color="red")
            axes[i * COLS + 1].axis("off")
            # Add true/predicted labels even if images failed to load
            axes[i * COLS].text(0.5, 0.5, f"True: {true_label}", horizontalalignment='center', verticalalignment='center', transform=axes[i * COLS].transAxes, color='black', fontsize=10)
            title_color = "green" if true_label == predicted_label else "red"
            axes[i * COLS + 1].text(0.5, 0.5, f"Pred: {predicted_label}", horizontalalignment='center', verticalalignment='center', transform=axes[i * COLS + 1].transAxes, color=title_color, fontsize=10)


    plt.tight_layout() # Adjust layout
    # Save the grid image
    output_path = os.path.join(OUTPUT_DIR, "gradcam_grid.png")
    plt.savefig(output_path)
    print(f"✅ Grad-CAM grid image saved to: {os.path.abspath(output_path)}")
    plt.show()

elif not target_layer:
     print("Cannot visualize Grad-CAM grid because the target convolutional layer was not found.")
else:
    print("No images available in the filtered list to display Grad-CAM grid.")

# Detach hooks if they were registered
if backward_hook_handle:
    backward_hook_handle.remove()
if forward_hook_handle:
    forward_hook_handle.remove()
# Out:
# ✅ Grad-CAM grid output will be saved to: /content/results
# ✅ Loaded predictions from: /content/outputs/test_predictions.csv
# ✅ Found 1 misclassified images.
# ...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Attempting to load model from: /content/content/best_model/final_best_resnet18.pth
# ✅ Model weights loaded successfully.
#
# Generating Grad-CAM grid...
# ...

# %% [markdown]
# For a **comprehensive explanation** of the methods, experiments, results, and discussion,
# Please refer to the detailed project report.
#
#
# The report includes:
# - **Detailed methodology:** Data preprocessing, model configuration, and hyperparameter choices.
# - **Experimental results:** Model accuracy, class-specific metrics, and confusion analysis.
# - **Grad-CAM interpretations:** Insights into model focus and diagnostic relevance.
# - **Critical discussion:** Limitations, potential improvements, and future research directions.
